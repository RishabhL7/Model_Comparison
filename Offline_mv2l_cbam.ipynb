# %% [markdown]
# <a href="https://colab.research.google.com/github/RishabhL7/Model_Comparison/blob/main/Offline_mv2l_cbam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import os
import keras
from tqdm import tqdm
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img

# %%
# !nvidia-smi
# Out:
# Sun Mar 13 07:22:15 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   38C    P0    27W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from google.colab import drive
drive.mount('/content/drive/', force_remount=True)
# Out:
# Mounted at /content/drive/

# %% [markdown]
# #Data Loading

# %%
IMG_WIDTH = 320
IMG_HEIGHT = 320
IMG_CHANNELS = 3

# %%
# !unzip '/content/drive/MyDrive/Data.zip'

# %%
path = "//content/Data/hand_data_train/colour"
maskpath = "/content/Data/hand_data_train/segmentation"

X_train = np.zeros((len(os.listdir(path)), IMG_HEIGHT, IMG_WIDTH,IMG_CHANNELS),dtype=np.uint8)
Y_train = np.zeros((len(os.listdir(maskpath)), IMG_HEIGHT, IMG_WIDTH,1))
print('creating input data')
n=0
for name in tqdm(os.listdir(path)):
    newpath = os.path.join(path,name)
    img=cv2.imread(newpath)
    img=cv2.resize(img,(IMG_WIDTH,IMG_HEIGHT))
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    X_train[n]=img
    n+=1

m=0
for name in tqdm(os.listdir(maskpath)):
    newmaskpath = os.path.join(maskpath,name)
    mpg=cv2.imread(newmaskpath)
    mpg=cv2.resize(mpg,(IMG_WIDTH,IMG_HEIGHT))
    mpg = cv2.cvtColor(mpg, cv2.COLOR_BGR2GRAY)
    ret, mpg = cv2.threshold(mpg, 120, 255, cv2.THRESH_BINARY)
    mpg=np.expand_dims(mpg,axis=-1)
    Y_train[m]=mpg/255
    m+=1
# Out:
# creating input data
# 100%|██████████| 2000/2000 [00:17<00:00, 116.65it/s]
# 100%|██████████| 2000/2000 [00:04<00:00, 407.83it/s]

# %%
path = "/content/Data/hand_data_test/colour"
maskpath = "/content/Data/hand_data_test/segmentation"
p1 = os.listdir(path)
p1.sort()

m1 = os.listdir(maskpath)
m1.sort()

X_test = np.zeros((len(os.listdir(path)), IMG_HEIGHT, IMG_WIDTH,IMG_CHANNELS),dtype=np.uint8)
Y_test = np.zeros((len(os.listdir(maskpath)), IMG_HEIGHT, IMG_WIDTH,1))
print('creating test data')
n=0
for name in tqdm(p1):
    newpath = os.path.join(path,name)
    img=cv2.imread(newpath)
    img=cv2.resize(img,(IMG_WIDTH,IMG_HEIGHT))
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    X_test[n]=img
    n+=1

m=0
for name in tqdm(m1):
    newmaskpath = os.path.join(maskpath,name)
    mpg=cv2.imread(newmaskpath)
    mpg=cv2.resize(mpg,(IMG_WIDTH,IMG_HEIGHT))
    mpg = cv2.cvtColor(mpg, cv2.COLOR_BGR2GRAY)
    ret, mpg = cv2.threshold(mpg, 120, 255, cv2.THRESH_BINARY)
    mpg=np.expand_dims(mpg,axis=-1)
    Y_test[m]=mpg/255
    m+=1
# Out:
# creating test data
# 100%|██████████| 1000/1000 [00:08<00:00, 114.65it/s]
# 100%|██████████| 1000/1000 [00:02<00:00, 389.06it/s]

# %%
plt.imshow(array_to_img(X_train[0]))

# %%
plt.imshow(array_to_img(Y_train[0]))

# %%
print(X_train.shape, Y_train.shape)
# Out:
# (2000, 320, 320, 3) (2000, 320, 320, 1)

# %% [markdown]
# # AEC_EE Model

# %%
from tensorflow.keras.layers import Conv2D, Activation, BatchNormalization
from tensorflow.keras.layers import UpSampling2D, Input, Concatenate, Conv2DTranspose, Add, AveragePooling2D
from tensorflow.keras.models import Model
from tensorflow.keras import backend as K
from tensorflow.keras.layers import *

# %%
def cbam_block(cbam_feature, ratio=8):
	"""Contains the implementation of Convolutional Block Attention Module(CBAM) block.
	As described in https://arxiv.org/abs/1807.06521.
	"""
	
	cbam_feature = channel_attention(cbam_feature, ratio)
	cbam_feature = spatial_attention(cbam_feature)
	return cbam_feature

# %%
def channel_attention(input_feature, ratio=8):
	
	channel_axis = 1 if K.image_data_format() == "channels_first" else -1
	channel = input_feature.shape[channel_axis]
	
	shared_layer_one = Dense(channel//ratio,
							 activation='relu',
							 kernel_initializer='he_normal',
							 use_bias=True,
							 bias_initializer='zeros')
	shared_layer_two = Dense(channel,
							 kernel_initializer='he_normal',
							 use_bias=True,
							 bias_initializer='zeros')
	
	avg_pool = GlobalAveragePooling2D()(input_feature)    
	avg_pool = Reshape((1,1,channel))(avg_pool)
	assert avg_pool.shape[1:] == (1,1,channel)
	avg_pool = shared_layer_one(avg_pool)
	assert avg_pool.shape[1:] == (1,1,channel//ratio)
	avg_pool = shared_layer_two(avg_pool)
	assert avg_pool.shape[1:] == (1,1,channel)
	
	max_pool = GlobalMaxPooling2D()(input_feature)
	max_pool = Reshape((1,1,channel))(max_pool)
	assert max_pool.shape[1:] == (1,1,channel)
	max_pool = shared_layer_one(max_pool)
	assert max_pool.shape[1:] == (1,1,channel//ratio)
	max_pool = shared_layer_two(max_pool)
	assert max_pool.shape[1:] == (1,1,channel)
	
	cbam_feature = Add()([avg_pool,max_pool])
	cbam_feature = Activation('sigmoid')(cbam_feature)
	
	if K.image_data_format() == "channels_first":
		cbam_feature = Permute((3, 1, 2))(cbam_feature)
	
	return multiply([input_feature, cbam_feature])

# %%
def spatial_attention(input_feature):
	kernel_size = 3
	
	if K.image_data_format() == "channels_first":
		channel = input_feature.shape[1]
		cbam_feature = Permute((2,3,1))(input_feature)
	else:
		channel = input_feature.shape[-1]
		cbam_feature = input_feature
	
	avg_pool = Lambda(lambda x: K.mean(x, axis=3, keepdims=True))(cbam_feature)
	assert avg_pool.shape[-1] == 1
	max_pool = Lambda(lambda x: K.max(x, axis=3, keepdims=True))(cbam_feature)
	assert max_pool.shape[-1] == 1
	concat = Concatenate(axis=3)([avg_pool, max_pool])
	assert concat.shape[-1] == 2
	cbam_feature = Conv2D(filters = 1,
					kernel_size=kernel_size,
					strides=1,
					padding='same',
					activation='sigmoid',
					kernel_initializer='he_normal',
					use_bias=False)(concat)	
	assert cbam_feature.shape[-1] == 1
	
	if K.image_data_format() == "channels_first":
		cbam_feature = Permute((3, 1, 2))(cbam_feature)
		
	return multiply([input_feature, cbam_feature])

# %%
def ASPP(inputs):

    conv_filters = 64
    """ Image Pooling """
    shape = inputs.shape
    y1 = AveragePooling2D(pool_size=(shape[1], shape[2]))(inputs)
    y1 = Conv2D(conv_filters, 1, padding="same", use_bias=False)(y1)
    y1 = BatchNormalization()(y1)
    y1 = Activation("relu")(y1)
    y1 = UpSampling2D((shape[1], shape[2]), interpolation="bilinear")(y1)

    """ 1x1 conv """
    y2 = Conv2D(conv_filters, 1, padding="same", use_bias=False)(inputs)
    y2 = BatchNormalization()(y2)
    y2 = Activation("relu")(y2)

    """ 3x3 conv rate=6 """
    y3 = Conv2D(conv_filters, 3, padding="same", use_bias=False, dilation_rate=6)(inputs)
    y3 = BatchNormalization()(y3)
    y3 = Activation("relu")(y3)

    """ 3x3 conv rate=12 """
    y4 = Conv2D(conv_filters, 3, padding="same", use_bias=False, dilation_rate=12)(inputs)
    y4 = BatchNormalization()(y4)
    y4 = Activation("relu")(y4)

    """ 3x3 conv rate=18 """
    y5 = Conv2D(conv_filters, 3, padding="same", use_bias=False, dilation_rate=18)(inputs)
    y5 = BatchNormalization()(y5)
    y5 = Activation("relu")(y5)

    y = Concatenate()([y1, y2, y3, y4, y5])
    y = Conv2D(conv_filters, 1, padding="same", use_bias=False)(y)
    y = BatchNormalization()(y)
    y = Activation("relu")(y)

    return y

# %%
"""Skip connections as per SM Models LINKnet with backbone mobilenetv2"""

# LATEST MODEL - LINKNET only

def build_LinkNet_mobilenetv2():    
  model = tf.keras.applications.MobileNetV2(include_top=False, weights = None,input_shape=(320, 320,3))

  """ Skip Connections """

  s1 = model.get_layer("block_1_expand_relu").output         ## (160, 160)
  s1 = cbam_block(s1)
  s2 = model.get_layer("block_3_expand_relu").output         ## ( 80, 80)
  s2 = cbam_block(s2)
  s3 = model.get_layer("block_6_expand_relu").output         ## (40, 40)
  s3 = cbam_block(s3)
  s4 = model.get_layer("block_13_expand_relu").output         ## (20, 20)
  s4 = cbam_block(s4)

  #print(s1.shape, s2.shape, s3.shape, s4.shape)

  """ Bridge """

  b1 = model.get_layer("out_relu").output
  #b1 = ASPP(b1)
  #print(b1.shape)

  """ Decoder """
  x = Conv2D(320, (1,1), kernel_initializer='he_normal', padding = 'same')(b1)
  x = BatchNormalization()(x)
  x = Activation('relu')(x)

  x = tf.keras.layers.UpSampling2D( size=(2, 2), interpolation='nearest')(x)

  x = Conv2D(320, (3,3), kernel_initializer='he_normal', padding = 'same')(x)
  x = BatchNormalization()(x)
  x = Activation('relu')(x)

  x = Conv2D(576, (1,1), kernel_initializer='he_normal', padding = 'same')(x)
  x = BatchNormalization()(x)
  x = Activation('relu')(x)

  x = Add()([x, s4]) # ADD 1

  x = Conv2D(144, (1,1), kernel_initializer='he_normal', padding = 'same')(x)
  x = BatchNormalization()(x)
  x = Activation('relu')(x)

  x = tf.keras.layers.UpSampling2D( size=(2, 2), interpolation='nearest')(x)

  x = Conv2D(144, (3,3), kernel_initializer='he_normal', padding = 'same')(x)
  x = BatchNormalization()(x)
  x = Activation('relu')(x)

  x = Conv2D(192, (1,1), kernel_initializer='he_normal', padding = 'same')(x)
  x = BatchNormalization()(x)
  x = Activation('relu')(x)

  x = Add()([x, s3]) # ADD 2

  x = Conv2D(48, (1,1), kernel_initializer='he_normal', padding = 'same')(x)
  x = BatchNormalization()(x)
  x = Activation('relu')(x)

  x = tf.keras.layers.UpSampling2D( size=(2, 2), interpolation='nearest')(x)

  x = Conv2D(48, (3,3), kernel_initializer='he_normal', padding = 'same')(x)
  x = BatchNormalization()(x)
  x = Activation('relu')(x)

  x = Conv2D(144, (1,1), kernel_initializer='he_normal', padding = 'same')(x)
  x = BatchNormalization()(x)
  x = Activation('relu')(x)

  x = Add()([x, s2]) # ADD 3

  x = Conv2D(36, (1,1), kernel_initializer='he_normal', padding = 'same')(x)
  x = BatchNormalization()(x)
  x = Activation('relu')(x)

  x = tf.keras.layers.UpSampling2D( size=(2, 2), interpolation='nearest')(x)

  x = Conv2D(36, (3,3), kernel_initializer='he_normal', padding = 'same')(x)
  x = BatchNormalization()(x)
  x = Activation('relu')(x)

  x = Conv2D(96, (1,1), kernel_initializer='he_normal', padding = 'same')(x)
  x = BatchNormalization()(x)
  x = Activation('relu')(x)

  x = Add()([x, s1]) # ADD 4

  x = Conv2D(24, (1,1), kernel_initializer='he_normal', padding = 'same')(x)
  x = BatchNormalization()(x)
  x = Activation('relu')(x)

  x = tf.keras.layers.UpSampling2D( size=(2, 2), interpolation='nearest')(x)

  x = Conv2D(24, (3,3), kernel_initializer='he_normal', padding = 'same')(x)
  x = BatchNormalization()(x)
  x = Activation('relu')(x)

  x = Conv2D(16, (1,1), kernel_initializer='he_normal', padding = 'same')(x)
  x = BatchNormalization()(x)
  x = Activation('relu')(x)

  

  outputs = Conv2D(1, 1, kernel_initializer='he_normal',padding="same")(x)
  outputs = Activation('sigmoid')(outputs)

  model = keras.models.Model(inputs=[model.input], outputs=[outputs])  

  #print(model.summary())

  return model

# %%
model = build_LinkNet_mobilenetv2()
print(model.summary())
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 320, 320, 3  0           []
#                                 )]
#
#  Conv1 (Conv2D)                 (None, 160, 160, 32  864         ['input_2[0][0]']
#                                 )
#
#  bn_Conv1 (BatchNormalization)  (None, 160, 160, 32  128         ['Conv1[0][0]']
#                                 )
#
#  Conv1_relu (ReLU)              (None, 160, 160, 32  0           ['bn_Conv1[0][0]']
#                                 )
#
#  expanded_conv_depthwise (Depth  (None, 160, 160, 32  288        ['Conv1_relu[0][0]']
#  wiseConv2D)                    )
#
#  expanded_conv_depthwise_BN (Ba  (None, 160, 160, 32  128        ['expanded_conv_depthwise[0][0]']
#  tchNormalization)              )
#
#  expanded_conv_depthwise_relu (  (None, 160, 160, 32  0          ['expanded_conv_depthwise_BN[0][0
#  ReLU)                          )                                ]']
#
#  expanded_conv_project (Conv2D)  (None, 160, 160, 16  512        ['expanded_conv_depthwise_relu[0]
#                                 )                                [0]']
#
#  expanded_conv_project_BN (Batc  (None, 160, 160, 16  64         ['expanded_conv_project[0][0]']
#  hNormalization)                )
#
#  block_1_expand (Conv2D)        (None, 160, 160, 96  1536        ['expanded_conv_project_BN[0][0]'
#                                 )                                ]
#
#  block_1_expand_BN (BatchNormal  (None, 160, 160, 96  384        ['block_1_expand[0][0]']
#  ization)                       )
#
#  block_1_expand_relu (ReLU)     (None, 160, 160, 96  0           ['block_1_expand_BN[0][0]']
#                                 )
#
#  block_1_pad (ZeroPadding2D)    (None, 161, 161, 96  0           ['block_1_expand_relu[0][0]']
#                                 )
#
#  block_1_depthwise (DepthwiseCo  (None, 80, 80, 96)  864         ['block_1_pad[0][0]']
#  nv2D)
#
#  block_1_depthwise_BN (BatchNor  (None, 80, 80, 96)  384         ['block_1_depthwise[0][0]']
#  malization)
#
#  block_1_depthwise_relu (ReLU)  (None, 80, 80, 96)   0           ['block_1_depthwise_BN[0][0]']
#
#  block_1_project (Conv2D)       (None, 80, 80, 24)   2304        ['block_1_depthwise_relu[0][0]']
#
#  block_1_project_BN (BatchNorma  (None, 80, 80, 24)  96          ['block_1_project[0][0]']
#  lization)
#
#  block_2_expand (Conv2D)        (None, 80, 80, 144)  3456        ['block_1_project_BN[0][0]']
#
#  block_2_expand_BN (BatchNormal  (None, 80, 80, 144)  576        ['block_2_expand[0][0]']
#  ization)
#
#  block_2_expand_relu (ReLU)     (None, 80, 80, 144)  0           ['block_2_expand_BN[0][0]']
#
#  block_2_depthwise (DepthwiseCo  (None, 80, 80, 144)  1296       ['block_2_expand_relu[0][0]']
#  nv2D)
#
#  block_2_depthwise_BN (BatchNor  (None, 80, 80, 144)  576        ['block_2_depthwise[0][0]']
#  malization)
#
#  block_2_depthwise_relu (ReLU)  (None, 80, 80, 144)  0           ['block_2_depthwise_BN[0][0]']
#
#  block_2_project (Conv2D)       (None, 80, 80, 24)   3456        ['block_2_depthwise_relu[0][0]']
#
#  block_2_project_BN (BatchNorma  (None, 80, 80, 24)  96          ['block_2_project[0][0]']
#  lization)
#
#  block_2_add (Add)              (None, 80, 80, 24)   0           ['block_1_project_BN[0][0]',
#                                                                   'block_2_project_BN[0][0]']
#
#  block_3_expand (Conv2D)        (None, 80, 80, 144)  3456        ['block_2_add[0][0]']
#
#  block_3_expand_BN (BatchNormal  (None, 80, 80, 144)  576        ['block_3_expand[0][0]']
#  ization)
#
#  block_3_expand_relu (ReLU)     (None, 80, 80, 144)  0           ['block_3_expand_BN[0][0]']
#
#  block_3_pad (ZeroPadding2D)    (None, 81, 81, 144)  0           ['block_3_expand_relu[0][0]']
#
#  block_3_depthwise (DepthwiseCo  (None, 40, 40, 144)  1296       ['block_3_pad[0][0]']
#  nv2D)
#
#  block_3_depthwise_BN (BatchNor  (None, 40, 40, 144)  576        ['block_3_depthwise[0][0]']
#  malization)
#
#  block_3_depthwise_relu (ReLU)  (None, 40, 40, 144)  0           ['block_3_depthwise_BN[0][0]']
#
#  block_3_project (Conv2D)       (None, 40, 40, 32)   4608        ['block_3_depthwise_relu[0][0]']
#
#  block_3_project_BN (BatchNorma  (None, 40, 40, 32)  128         ['block_3_project[0][0]']
#  lization)
#
#  block_4_expand (Conv2D)        (None, 40, 40, 192)  6144        ['block_3_project_BN[0][0]']
#
#  block_4_expand_BN (BatchNormal  (None, 40, 40, 192)  768        ['block_4_expand[0][0]']
#  ization)
#
#  block_4_expand_relu (ReLU)     (None, 40, 40, 192)  0           ['block_4_expand_BN[0][0]']
#
#  block_4_depthwise (DepthwiseCo  (None, 40, 40, 192)  1728       ['block_4_expand_relu[0][0]']
#  nv2D)
#
#  block_4_depthwise_BN (BatchNor  (None, 40, 40, 192)  768        ['block_4_depthwise[0][0]']
#  malization)
#
#  block_4_depthwise_relu (ReLU)  (None, 40, 40, 192)  0           ['block_4_depthwise_BN[0][0]']
#
#  block_4_project (Conv2D)       (None, 40, 40, 32)   6144        ['block_4_depthwise_relu[0][0]']
#
#  block_4_project_BN (BatchNorma  (None, 40, 40, 32)  128         ['block_4_project[0][0]']
#  lization)
#
#  block_4_add (Add)              (None, 40, 40, 32)   0           ['block_3_project_BN[0][0]',
#                                                                   'block_4_project_BN[0][0]']
#
#  block_5_expand (Conv2D)        (None, 40, 40, 192)  6144        ['block_4_add[0][0]']
#
#  block_5_expand_BN (BatchNormal  (None, 40, 40, 192)  768        ['block_5_expand[0][0]']
#  ization)
#
#  block_5_expand_relu (ReLU)     (None, 40, 40, 192)  0           ['block_5_expand_BN[0][0]']
#
#  block_5_depthwise (DepthwiseCo  (None, 40, 40, 192)  1728       ['block_5_expand_relu[0][0]']
#  nv2D)
#
#  block_5_depthwise_BN (BatchNor  (None, 40, 40, 192)  768        ['block_5_depthwise[0][0]']
#  malization)
#
#  block_5_depthwise_relu (ReLU)  (None, 40, 40, 192)  0           ['block_5_depthwise_BN[0][0]']
#
#  block_5_project (Conv2D)       (None, 40, 40, 32)   6144        ['block_5_depthwise_relu[0][0]']
#
#  block_5_project_BN (BatchNorma  (None, 40, 40, 32)  128         ['block_5_project[0][0]']
#  lization)
#
#  block_5_add (Add)              (None, 40, 40, 32)   0           ['block_4_add[0][0]',
#                                                                   'block_5_project_BN[0][0]']
#
#  block_6_expand (Conv2D)        (None, 40, 40, 192)  6144        ['block_5_add[0][0]']
#
#  block_6_expand_BN (BatchNormal  (None, 40, 40, 192)  768        ['block_6_expand[0][0]']
#  ization)
#
#  block_6_expand_relu (ReLU)     (None, 40, 40, 192)  0           ['block_6_expand_BN[0][0]']
#
#  block_6_pad (ZeroPadding2D)    (None, 41, 41, 192)  0           ['block_6_expand_relu[0][0]']
#
#  block_6_depthwise (DepthwiseCo  (None, 20, 20, 192)  1728       ['block_6_pad[0][0]']
#  nv2D)
#
#  block_6_depthwise_BN (BatchNor  (None, 20, 20, 192)  768        ['block_6_depthwise[0][0]']
#  malization)
#
#  block_6_depthwise_relu (ReLU)  (None, 20, 20, 192)  0           ['block_6_depthwise_BN[0][0]']
#
#  block_6_project (Conv2D)       (None, 20, 20, 64)   12288       ['block_6_depthwise_relu[0][0]']
#
#  block_6_project_BN (BatchNorma  (None, 20, 20, 64)  256         ['block_6_project[0][0]']
#  lization)
#
#  block_7_expand (Conv2D)        (None, 20, 20, 384)  24576       ['block_6_project_BN[0][0]']
#
#  block_7_expand_BN (BatchNormal  (None, 20, 20, 384)  1536       ['block_7_expand[0][0]']
#  ization)
#
#  block_7_expand_relu (ReLU)     (None, 20, 20, 384)  0           ['block_7_expand_BN[0][0]']
#
#  block_7_depthwise (DepthwiseCo  (None, 20, 20, 384)  3456       ['block_7_expand_relu[0][0]']
#  nv2D)
#
#  block_7_depthwise_BN (BatchNor  (None, 20, 20, 384)  1536       ['block_7_depthwise[0][0]']
#  malization)
#
#  block_7_depthwise_relu (ReLU)  (None, 20, 20, 384)  0           ['block_7_depthwise_BN[0][0]']
#
#  block_7_project (Conv2D)       (None, 20, 20, 64)   24576       ['block_7_depthwise_relu[0][0]']
#
#  block_7_project_BN (BatchNorma  (None, 20, 20, 64)  256         ['block_7_project[0][0]']
#  lization)
#
#  block_7_add (Add)              (None, 20, 20, 64)   0           ['block_6_project_BN[0][0]',
#                                                                   'block_7_project_BN[0][0]']
#
#  block_8_expand (Conv2D)        (None, 20, 20, 384)  24576       ['block_7_add[0][0]']
#
#  block_8_expand_BN (BatchNormal  (None, 20, 20, 384)  1536       ['block_8_expand[0][0]']
#  ization)
#
#  block_8_expand_relu (ReLU)     (None, 20, 20, 384)  0           ['block_8_expand_BN[0][0]']
#
#  block_8_depthwise (DepthwiseCo  (None, 20, 20, 384)  3456       ['block_8_expand_relu[0][0]']
#  nv2D)
#
#  block_8_depthwise_BN (BatchNor  (None, 20, 20, 384)  1536       ['block_8_depthwise[0][0]']
#  malization)
#
#  block_8_depthwise_relu (ReLU)  (None, 20, 20, 384)  0           ['block_8_depthwise_BN[0][0]']
#
#  block_8_project (Conv2D)       (None, 20, 20, 64)   24576       ['block_8_depthwise_relu[0][0]']
#
#  block_8_project_BN (BatchNorma  (None, 20, 20, 64)  256         ['block_8_project[0][0]']
#  lization)
#
#  block_8_add (Add)              (None, 20, 20, 64)   0           ['block_7_add[0][0]',
#                                                                   'block_8_project_BN[0][0]']
#
#  block_9_expand (Conv2D)        (None, 20, 20, 384)  24576       ['block_8_add[0][0]']
#
#  block_9_expand_BN (BatchNormal  (None, 20, 20, 384)  1536       ['block_9_expand[0][0]']
#  ization)
#
#  block_9_expand_relu (ReLU)     (None, 20, 20, 384)  0           ['block_9_expand_BN[0][0]']
#
#  block_9_depthwise (DepthwiseCo  (None, 20, 20, 384)  3456       ['block_9_expand_relu[0][0]']
#  nv2D)
#
#  block_9_depthwise_BN (BatchNor  (None, 20, 20, 384)  1536       ['block_9_depthwise[0][0]']
#  malization)
#
#  block_9_depthwise_relu (ReLU)  (None, 20, 20, 384)  0           ['block_9_depthwise_BN[0][0]']
#
#  block_9_project (Conv2D)       (None, 20, 20, 64)   24576       ['block_9_depthwise_relu[0][0]']
#
#  block_9_project_BN (BatchNorma  (None, 20, 20, 64)  256         ['block_9_project[0][0]']
#  lization)
#
#  block_9_add (Add)              (None, 20, 20, 64)   0           ['block_8_add[0][0]',
#                                                                   'block_9_project_BN[0][0]']
#
#  block_10_expand (Conv2D)       (None, 20, 20, 384)  24576       ['block_9_add[0][0]']
#
#  block_10_expand_BN (BatchNorma  (None, 20, 20, 384)  1536       ['block_10_expand[0][0]']
#  lization)
#
#  block_10_expand_relu (ReLU)    (None, 20, 20, 384)  0           ['block_10_expand_BN[0][0]']
#
#  block_10_depthwise (DepthwiseC  (None, 20, 20, 384)  3456       ['block_10_expand_relu[0][0]']
#  onv2D)
#
#  block_10_depthwise_BN (BatchNo  (None, 20, 20, 384)  1536       ['block_10_depthwise[0][0]']
#  rmalization)
#
#  block_10_depthwise_relu (ReLU)  (None, 20, 20, 384)  0          ['block_10_depthwise_BN[0][0]']
#
#  block_10_project (Conv2D)      (None, 20, 20, 96)   36864       ['block_10_depthwise_relu[0][0]']
#
#  block_10_project_BN (BatchNorm  (None, 20, 20, 96)  384         ['block_10_project[0][0]']
#  alization)
#
#  block_11_expand (Conv2D)       (None, 20, 20, 576)  55296       ['block_10_project_BN[0][0]']
#
#  block_11_expand_BN (BatchNorma  (None, 20, 20, 576)  2304       ['block_11_expand[0][0]']
#  lization)
#
#  block_11_expand_relu (ReLU)    (None, 20, 20, 576)  0           ['block_11_expand_BN[0][0]']
#
#  block_11_depthwise (DepthwiseC  (None, 20, 20, 576)  5184       ['block_11_expand_relu[0][0]']
#  onv2D)
#
#  block_11_depthwise_BN (BatchNo  (None, 20, 20, 576)  2304       ['block_11_depthwise[0][0]']
#  rmalization)
#
#  block_11_depthwise_relu (ReLU)  (None, 20, 20, 576)  0          ['block_11_depthwise_BN[0][0]']
#
#  block_11_project (Conv2D)      (None, 20, 20, 96)   55296       ['block_11_depthwise_relu[0][0]']
#
#  block_11_project_BN (BatchNorm  (None, 20, 20, 96)  384         ['block_11_project[0][0]']
#  alization)
#
#  block_11_add (Add)             (None, 20, 20, 96)   0           ['block_10_project_BN[0][0]',
#                                                                   'block_11_project_BN[0][0]']
#
#  block_12_expand (Conv2D)       (None, 20, 20, 576)  55296       ['block_11_add[0][0]']
#
#  block_12_expand_BN (BatchNorma  (None, 20, 20, 576)  2304       ['block_12_expand[0][0]']
#  lization)
#
#  block_12_expand_relu (ReLU)    (None, 20, 20, 576)  0           ['block_12_expand_BN[0][0]']
#
#  block_12_depthwise (DepthwiseC  (None, 20, 20, 576)  5184       ['block_12_expand_relu[0][0]']
#  onv2D)
#
#  block_12_depthwise_BN (BatchNo  (None, 20, 20, 576)  2304       ['block_12_depthwise[0][0]']
#  rmalization)
#
#  block_12_depthwise_relu (ReLU)  (None, 20, 20, 576)  0          ['block_12_depthwise_BN[0][0]']
#
#  block_12_project (Conv2D)      (None, 20, 20, 96)   55296       ['block_12_depthwise_relu[0][0]']
#
#  block_12_project_BN (BatchNorm  (None, 20, 20, 96)  384         ['block_12_project[0][0]']
#  alization)
#
#  block_12_add (Add)             (None, 20, 20, 96)   0           ['block_11_add[0][0]',
#                                                                   'block_12_project_BN[0][0]']
#
#  block_13_expand (Conv2D)       (None, 20, 20, 576)  55296       ['block_12_add[0][0]']
#
#  block_13_expand_BN (BatchNorma  (None, 20, 20, 576)  2304       ['block_13_expand[0][0]']
#  lization)
#
#  block_13_expand_relu (ReLU)    (None, 20, 20, 576)  0           ['block_13_expand_BN[0][0]']
#
#  block_13_pad (ZeroPadding2D)   (None, 21, 21, 576)  0           ['block_13_expand_relu[0][0]']
#
#  block_13_depthwise (DepthwiseC  (None, 10, 10, 576)  5184       ['block_13_pad[0][0]']
#  onv2D)
#
#  block_13_depthwise_BN (BatchNo  (None, 10, 10, 576)  2304       ['block_13_depthwise[0][0]']
#  rmalization)
#
#  block_13_depthwise_relu (ReLU)  (None, 10, 10, 576)  0          ['block_13_depthwise_BN[0][0]']
#
#  block_13_project (Conv2D)      (None, 10, 10, 160)  92160       ['block_13_depthwise_relu[0][0]']
#
#  block_13_project_BN (BatchNorm  (None, 10, 10, 160)  640        ['block_13_project[0][0]']
#  alization)
#
#  block_14_expand (Conv2D)       (None, 10, 10, 960)  153600      ['block_13_project_BN[0][0]']
#
#  block_14_expand_BN (BatchNorma  (None, 10, 10, 960)  3840       ['block_14_expand[0][0]']
#  lization)
#
#  block_14_expand_relu (ReLU)    (None, 10, 10, 960)  0           ['block_14_expand_BN[0][0]']
#
#  block_14_depthwise (DepthwiseC  (None, 10, 10, 960)  8640       ['block_14_expand_relu[0][0]']
#  onv2D)
#
#  block_14_depthwise_BN (BatchNo  (None, 10, 10, 960)  3840       ['block_14_depthwise[0][0]']
#  rmalization)
#
#  block_14_depthwise_relu (ReLU)  (None, 10, 10, 960)  0          ['block_14_depthwise_BN[0][0]']
#
#  block_14_project (Conv2D)      (None, 10, 10, 160)  153600      ['block_14_depthwise_relu[0][0]']
#
#  block_14_project_BN (BatchNorm  (None, 10, 10, 160)  640        ['block_14_project[0][0]']
#  alization)
#
#  block_14_add (Add)             (None, 10, 10, 160)  0           ['block_13_project_BN[0][0]',
#                                                                   'block_14_project_BN[0][0]']
#
#  block_15_expand (Conv2D)       (None, 10, 10, 960)  153600      ['block_14_add[0][0]']
#
#  block_15_expand_BN (BatchNorma  (None, 10, 10, 960)  3840       ['block_15_expand[0][0]']
#  lization)
#
#  block_15_expand_relu (ReLU)    (None, 10, 10, 960)  0           ['block_15_expand_BN[0][0]']
#
#  block_15_depthwise (DepthwiseC  (None, 10, 10, 960)  8640       ['block_15_expand_relu[0][0]']
#  onv2D)
#
#  block_15_depthwise_BN (BatchNo  (None, 10, 10, 960)  3840       ['block_15_depthwise[0][0]']
#  rmalization)
#
#  block_15_depthwise_relu (ReLU)  (None, 10, 10, 960)  0          ['block_15_depthwise_BN[0][0]']
#
#  block_15_project (Conv2D)      (None, 10, 10, 160)  153600      ['block_15_depthwise_relu[0][0]']
#
#  block_15_project_BN (BatchNorm  (None, 10, 10, 160)  640        ['block_15_project[0][0]']
#  alization)
#
#  block_15_add (Add)             (None, 10, 10, 160)  0           ['block_14_add[0][0]',
#                                                                   'block_15_project_BN[0][0]']
#
#  block_16_expand (Conv2D)       (None, 10, 10, 960)  153600      ['block_15_add[0][0]']
#
#  block_16_expand_BN (BatchNorma  (None, 10, 10, 960)  3840       ['block_16_expand[0][0]']
#  lization)
#
#  block_16_expand_relu (ReLU)    (None, 10, 10, 960)  0           ['block_16_expand_BN[0][0]']
#
#  block_16_depthwise (DepthwiseC  (None, 10, 10, 960)  8640       ['block_16_expand_relu[0][0]']
#  onv2D)
#
#  block_16_depthwise_BN (BatchNo  (None, 10, 10, 960)  3840       ['block_16_depthwise[0][0]']
#  rmalization)
#
#  block_16_depthwise_relu (ReLU)  (None, 10, 10, 960)  0          ['block_16_depthwise_BN[0][0]']
#
#  block_16_project (Conv2D)      (None, 10, 10, 320)  307200      ['block_16_depthwise_relu[0][0]']
#
#  block_16_project_BN (BatchNorm  (None, 10, 10, 320)  1280       ['block_16_project[0][0]']
#  alization)
#
#  Conv_1 (Conv2D)                (None, 10, 10, 1280  409600      ['block_16_project_BN[0][0]']
#                                 )
#
#  Conv_1_bn (BatchNormalization)  (None, 10, 10, 1280  5120       ['Conv_1[0][0]']
#                                 )
#
#  out_relu (ReLU)                (None, 10, 10, 1280  0           ['Conv_1_bn[0][0]']
#                                 )
#
#  global_average_pooling2d_7 (Gl  (None, 576)         0           ['block_13_expand_relu[0][0]']
#  obalAveragePooling2D)
#
#  global_max_pooling2d_7 (Global  (None, 576)         0           ['block_13_expand_relu[0][0]']
#  MaxPooling2D)
#
#  conv2d_24 (Conv2D)             (None, 10, 10, 320)  409920      ['out_relu[0][0]']
#
#  reshape_14 (Reshape)           (None, 1, 1, 576)    0           ['global_average_pooling2d_7[0][0
#                                                                  ]']
#
#  reshape_15 (Reshape)           (None, 1, 1, 576)    0           ['global_max_pooling2d_7[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 10, 10, 320)  1280       ['conv2d_24[0][0]']
#  ormalization)
#
#  dense_14 (Dense)               (None, 1, 1, 72)     41544       ['reshape_14[0][0]',
#                                                                   'reshape_15[0][0]']
#
#  activation_24 (Activation)     (None, 10, 10, 320)  0           ['batch_normalization_15[0][0]']
#
#  dense_15 (Dense)               (None, 1, 1, 576)    42048       ['dense_14[0][0]',
#                                                                   'dense_14[1][0]']
#
#  up_sampling2d_5 (UpSampling2D)  (None, 20, 20, 320)  0          ['activation_24[0][0]']
#
#  add_11 (Add)                   (None, 1, 1, 576)    0           ['dense_15[0][0]',
#                                                                   'dense_15[1][0]']
#
#  conv2d_25 (Conv2D)             (None, 20, 20, 320)  921920      ['up_sampling2d_5[0][0]']
#
#  activation_23 (Activation)     (None, 1, 1, 576)    0           ['add_11[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 20, 20, 320)  1280       ['conv2d_25[0][0]']
#  ormalization)
#
#  multiply_14 (Multiply)         (None, 20, 20, 576)  0           ['block_13_expand_relu[0][0]',
#                                                                   'activation_23[0][0]']
#
#  activation_25 (Activation)     (None, 20, 20, 320)  0           ['batch_normalization_16[0][0]']
#
#  lambda_14 (Lambda)             (None, 20, 20, 1)    0           ['multiply_14[0][0]']
#
#  lambda_15 (Lambda)             (None, 20, 20, 1)    0           ['multiply_14[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 20, 20, 576)  184896      ['activation_25[0][0]']
#
#  concatenate_7 (Concatenate)    (None, 20, 20, 2)    0           ['lambda_14[0][0]',
#                                                                   'lambda_15[0][0]']
#
#  batch_normalization_17 (BatchN  (None, 20, 20, 576)  2304       ['conv2d_26[0][0]']
#  ormalization)
#
#  conv2d_23 (Conv2D)             (None, 20, 20, 1)    18          ['concatenate_7[0][0]']
#
#  activation_26 (Activation)     (None, 20, 20, 576)  0           ['batch_normalization_17[0][0]']
#
#  multiply_15 (Multiply)         (None, 20, 20, 576)  0           ['multiply_14[0][0]',
#                                                                   'conv2d_23[0][0]']
#
#  add_12 (Add)                   (None, 20, 20, 576)  0           ['activation_26[0][0]',
#                                                                   'multiply_15[0][0]']
#
#  global_average_pooling2d_6 (Gl  (None, 192)         0           ['block_6_expand_relu[0][0]']
#  obalAveragePooling2D)
#
#  global_max_pooling2d_6 (Global  (None, 192)         0           ['block_6_expand_relu[0][0]']
#  MaxPooling2D)
#
#  conv2d_27 (Conv2D)             (None, 20, 20, 144)  83088       ['add_12[0][0]']
#
#  reshape_12 (Reshape)           (None, 1, 1, 192)    0           ['global_average_pooling2d_6[0][0
#                                                                  ]']
#
#  reshape_13 (Reshape)           (None, 1, 1, 192)    0           ['global_max_pooling2d_6[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 20, 20, 144)  576        ['conv2d_27[0][0]']
#  ormalization)
#
#  dense_12 (Dense)               (None, 1, 1, 24)     4632        ['reshape_12[0][0]',
#                                                                   'reshape_13[0][0]']
#
#  activation_27 (Activation)     (None, 20, 20, 144)  0           ['batch_normalization_18[0][0]']
#
# ...
#
#  reshape_10 (Reshape)           (None, 1, 1, 144)    0           ['global_average_pooling2d_5[0][0
#                                                                  ]']
#
#  reshape_11 (Reshape)           (None, 1, 1, 144)    0           ['global_max_pooling2d_5[0][0]']
#
#  batch_normalization_21 (BatchN  (None, 40, 40, 48)  192         ['conv2d_30[0][0]']
#  ormalization)
#
#  dense_10 (Dense)               (None, 1, 1, 18)     2610        ['reshape_10[0][0]',
#                                                                   'reshape_11[0][0]']
#
#  activation_30 (Activation)     (None, 40, 40, 48)   0           ['batch_normalization_21[0][0]']
#
#  dense_11 (Dense)               (None, 1, 1, 144)    2736        ['dense_10[0][0]',
#                                                                   'dense_10[1][0]']
#
#  up_sampling2d_7 (UpSampling2D)  (None, 80, 80, 48)  0           ['activation_30[0][0]']
#
#  add_9 (Add)                    (None, 1, 1, 144)    0           ['dense_11[0][0]',
#                                                                   'dense_11[1][0]']
#
#  conv2d_31 (Conv2D)             (None, 80, 80, 48)   20784       ['up_sampling2d_7[0][0]']
#
#  activation_21 (Activation)     (None, 1, 1, 144)    0           ['add_9[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 80, 80, 48)  192         ['conv2d_31[0][0]']
#  ormalization)
#
#  multiply_10 (Multiply)         (None, 80, 80, 144)  0           ['block_3_expand_relu[0][0]',
#                                                                   'activation_21[0][0]']
#
#  activation_31 (Activation)     (None, 80, 80, 48)   0           ['batch_normalization_22[0][0]']
#
#  lambda_10 (Lambda)             (None, 80, 80, 1)    0           ['multiply_10[0][0]']
#
#  lambda_11 (Lambda)             (None, 80, 80, 1)    0           ['multiply_10[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 80, 80, 144)  7056        ['activation_31[0][0]']
#
#  concatenate_5 (Concatenate)    (None, 80, 80, 2)    0           ['lambda_10[0][0]',
#                                                                   'lambda_11[0][0]']
#
#  batch_normalization_23 (BatchN  (None, 80, 80, 144)  576        ['conv2d_32[0][0]']
#  ormalization)
#
#  conv2d_21 (Conv2D)             (None, 80, 80, 1)    18          ['concatenate_5[0][0]']
#
#  activation_32 (Activation)     (None, 80, 80, 144)  0           ['batch_normalization_23[0][0]']
#
#  multiply_11 (Multiply)         (None, 80, 80, 144)  0           ['multiply_10[0][0]',
#                                                                   'conv2d_21[0][0]']
#
#  add_14 (Add)                   (None, 80, 80, 144)  0           ['activation_32[0][0]',
#                                                                   'multiply_11[0][0]']
#
#  global_average_pooling2d_4 (Gl  (None, 96)          0           ['block_1_expand_relu[0][0]']
#  obalAveragePooling2D)
#
#  global_max_pooling2d_4 (Global  (None, 96)          0           ['block_1_expand_relu[0][0]']
#  MaxPooling2D)
#
#  conv2d_33 (Conv2D)             (None, 80, 80, 36)   5220        ['add_14[0][0]']
#
#  reshape_8 (Reshape)            (None, 1, 1, 96)     0           ['global_average_pooling2d_4[0][0
#                                                                  ]']
#
#  reshape_9 (Reshape)            (None, 1, 1, 96)     0           ['global_max_pooling2d_4[0][0]']
#
#  batch_normalization_24 (BatchN  (None, 80, 80, 36)  144         ['conv2d_33[0][0]']
#  ormalization)
#
#  dense_8 (Dense)                (None, 1, 1, 12)     1164        ['reshape_8[0][0]',
#                                                                   'reshape_9[0][0]']
#
#  activation_33 (Activation)     (None, 80, 80, 36)   0           ['batch_normalization_24[0][0]']
#
#  dense_9 (Dense)                (None, 1, 1, 96)     1248        ['dense_8[0][0]',
#                                                                   'dense_8[1][0]']
#
#  up_sampling2d_8 (UpSampling2D)  (None, 160, 160, 36  0          ['activation_33[0][0]']
#                                 )
#
#  add_8 (Add)                    (None, 1, 1, 96)     0           ['dense_9[0][0]',
#                                                                   'dense_9[1][0]']
#
#  conv2d_34 (Conv2D)             (None, 160, 160, 36  11700       ['up_sampling2d_8[0][0]']
#                                 )
#
#  activation_20 (Activation)     (None, 1, 1, 96)     0           ['add_8[0][0]']
#
#  batch_normalization_25 (BatchN  (None, 160, 160, 36  144        ['conv2d_34[0][0]']
#  ormalization)                  )
#
#  multiply_8 (Multiply)          (None, 160, 160, 96  0           ['block_1_expand_relu[0][0]',
#                                 )                                 'activation_20[0][0]']
#
#  activation_34 (Activation)     (None, 160, 160, 36  0           ['batch_normalization_25[0][0]']
#                                 )
#
#  lambda_8 (Lambda)              (None, 160, 160, 1)  0           ['multiply_8[0][0]']
#
#  lambda_9 (Lambda)              (None, 160, 160, 1)  0           ['multiply_8[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 160, 160, 96  3552        ['activation_34[0][0]']
#                                 )
#
#  concatenate_4 (Concatenate)    (None, 160, 160, 2)  0           ['lambda_8[0][0]',
#                                                                   'lambda_9[0][0]']
#
#  batch_normalization_26 (BatchN  (None, 160, 160, 96  384        ['conv2d_35[0][0]']
#  ormalization)                  )
#
#  conv2d_20 (Conv2D)             (None, 160, 160, 1)  18          ['concatenate_4[0][0]']
#
#  activation_35 (Activation)     (None, 160, 160, 96  0           ['batch_normalization_26[0][0]']
#                                 )
#
#  multiply_9 (Multiply)          (None, 160, 160, 96  0           ['multiply_8[0][0]',
#                                 )                                 'conv2d_20[0][0]']
#
#  add_15 (Add)                   (None, 160, 160, 96  0           ['activation_35[0][0]',
#                                 )                                 'multiply_9[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 160, 160, 24  2328        ['add_15[0][0]']
#                                 )
#
#  batch_normalization_27 (BatchN  (None, 160, 160, 24  96         ['conv2d_36[0][0]']
#  ormalization)                  )
#
#  activation_36 (Activation)     (None, 160, 160, 24  0           ['batch_normalization_27[0][0]']
#                                 )
#
#  up_sampling2d_9 (UpSampling2D)  (None, 320, 320, 24  0          ['activation_36[0][0]']
#                                 )
#
#  conv2d_37 (Conv2D)             (None, 320, 320, 24  5208        ['up_sampling2d_9[0][0]']
#                                 )
#
#  batch_normalization_28 (BatchN  (None, 320, 320, 24  96         ['conv2d_37[0][0]']
#  ormalization)                  )
#
#  activation_37 (Activation)     (None, 320, 320, 24  0           ['batch_normalization_28[0][0]']
#                                 )
#
#  conv2d_38 (Conv2D)             (None, 320, 320, 16  400         ['activation_37[0][0]']
#                                 )
#
#  batch_normalization_29 (BatchN  (None, 320, 320, 16  64         ['conv2d_38[0][0]']
#  ormalization)                  )
#
#  activation_38 (Activation)     (None, 320, 320, 16  0           ['batch_normalization_29[0][0]']
#                                 )
#
#  conv2d_39 (Conv2D)             (None, 320, 320, 1)  17          ['activation_38[0][0]']
#
#  activation_39 (Activation)     (None, 320, 320, 1)  0           ['conv2d_39[0][0]']
#
# ==================================================================================================
# Total params: 4,247,471
# Trainable params: 4,209,023
# Non-trainable params: 38,448
# __________________________________________________________________________________________________
# None

# %%
#Sanity check, view few mages
import random
import numpy as np
image_number = random.randint(0, len(X_train))
plt.figure(figsize=(12, 6))
plt.subplot(121)
plt.imshow(X_train[image_number])
plt.subplot(122)
plt.imshow(array_to_img(Y_train[image_number]), cmap='gray')
plt.show()

# %%
from tensorflow.keras.optimizers import Adam

# %%
def iou(y_true, y_pred):
    def f(y_true, y_pred):
        intersection = (y_true * y_pred).sum()
        union = y_true.sum() + y_pred.sum() - intersection
        x = (intersection + 1e-15) / (union + 1e-15)
        x = x.astype(np.float32)
        return x
    return tf.numpy_function(f, [y_true, y_pred], tf.float32)

smooth = 1e-15
def dice_coef(y_true, y_pred):
    y_true = tf.keras.layers.Flatten()(y_true)
    y_pred = tf.keras.layers.Flatten()(y_pred)
    intersection = tf.reduce_sum(y_true * y_pred)
    return (2. * intersection + smooth) / (tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) + smooth)

def dice_loss(y_true, y_pred):
    return 1.0 - dice_coef(y_true, y_pred)

# %%
model.compile(loss=dice_loss, optimizer=Adam(1e-4), metrics=[dice_coef, iou, "accuracy"])

# %%
# !pip install keras-flops

# %%
from keras_flops import get_flops
flops = get_flops(model, batch_size=16)
print(f"FLOPS: {flops / 10 ** 9:.03} G")

# %% [markdown]
# ## 500 epochs

# %% [markdown]
# BATCH SIZE = 16

# %%
path = "/content/drive/MyDrive/Colab Notebooks/Checkpoints_main/offline_mobv2link_cbam_lasttry"
os.mkdir(path)

# %%
checkpoint_path_segmentdeeplab = "/content/drive/MyDrive/Colab Notebooks/Checkpoints_main/pffline_mobv2link_cbam_lasttry/cp.ckpt"
model_checkpoint_segmentdeeplab = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path_segmentdeeplab,
                                                                     save_weights_only=True,
                                                                     monitor='val_iou',
                                                                     mode="max",
                                                                     save_best_only=True,
                                                                     verbose=1)

# %%
history = model.fit(X_train, Y_train, validation_data = (X_test, Y_test), batch_size=16, epochs=500, callbacks=[model_checkpoint_segmentdeeplab])
# Out:
# Epoch 1/500
# 125/125 [==============================] - ETA: 0s - loss: 0.7225 - dice_coef: 0.2775 - iou: 0.1624 - accuracy: 0.5201
# Epoch 1: val_iou improved from -inf to 0.09262, saving model to /content/drive/MyDrive/Colab Notebooks/Checkpoints_main/pffline_mobv2link_cbam_lasttry/cp.ckpt
# 125/125 [==============================] - 63s 372ms/step - loss: 0.7225 - dice_coef: 0.2775 - iou: 0.1624 - accuracy: 0.5201 - val_loss: 0.8311 - val_dice_coef: 0.1691 - val_iou: 0.0926 - val_accuracy: 0.8843
# Epoch 2/500
# 125/125 [==============================] - ETA: 0s - loss: 0.6326 - dice_coef: 0.3674 - iou: 0.2257 - accuracy: 0.7373
# Epoch 2: val_iou did not improve from 0.09262
# 125/125 [==============================] - 43s 348ms/step - loss: 0.6326 - dice_coef: 0.3674 - iou: 0.2257 - accuracy: 0.7373 - val_loss: 0.8488 - val_dice_coef: 0.1514 - val_iou: 0.0820 - val_accuracy: 0.8844
# Epoch 3/500
# 125/125 [==============================] - ETA: 0s - loss: 0.5916 - dice_coef: 0.4084 - iou: 0.2573 - accuracy: 0.8663
# Epoch 3: val_iou did not improve from 0.09262
# 125/125 [==============================] - 43s 348ms/step - loss: 0.5916 - dice_coef: 0.4084 - iou: 0.2573 - accuracy: 0.8663 - val_loss: 0.8527 - val_dice_coef: 0.1474 - val_iou: 0.0797 - val_accuracy: 0.8844
# Epoch 4/500
# 125/125 [==============================] - ETA: 0s - loss: 0.5604 - dice_coef: 0.4396 - iou: 0.2825 - accuracy: 0.9151
# Epoch 4: val_iou did not improve from 0.09262
# 125/125 [==============================] - 44s 350ms/step - loss: 0.5604 - dice_coef: 0.4396 - iou: 0.2825 - accuracy: 0.9151 - val_loss: 0.8550 - val_dice_coef: 0.1452 - val_iou: 0.0784 - val_accuracy: 0.8844
# Epoch 5/500
# 125/125 [==============================] - ETA: 0s - loss: 0.5299 - dice_coef: 0.4701 - iou: 0.3081 - accuracy: 0.9360
# Epoch 5: val_iou did not improve from 0.09262
# 125/125 [==============================] - 44s 349ms/step - loss: 0.5299 - dice_coef: 0.4701 - iou: 0.3081 - accuracy: 0.9360 - val_loss: 0.8642 - val_dice_coef: 0.1360 - val_iou: 0.0730 - val_accuracy: 0.8844
# Epoch 6/500
# 125/125 [==============================] - ETA: 0s - loss: 0.5038 - dice_coef: 0.4962 - iou: 0.3309 - accuracy: 0.9484
# Epoch 6: val_iou did not improve from 0.09262
# 125/125 [==============================] - 43s 346ms/step - loss: 0.5038 - dice_coef: 0.4962 - iou: 0.3309 - accuracy: 0.9484 - val_loss: 0.8704 - val_dice_coef: 0.1298 - val_iou: 0.0695 - val_accuracy: 0.8844
# Epoch 7/500
# 125/125 [==============================] - ETA: 0s - loss: 0.4798 - dice_coef: 0.5202 - iou: 0.3527 - accuracy: 0.9578
# Epoch 7: val_iou did not improve from 0.09262
# 125/125 [==============================] - 43s 348ms/step - loss: 0.4798 - dice_coef: 0.5202 - iou: 0.3527 - accuracy: 0.9578 - val_loss: 0.8765 - val_dice_coef: 0.1236 - val_iou: 0.0659 - val_accuracy: 0.8844
# Epoch 8/500
# 125/125 [==============================] - ETA: 0s - loss: 0.4570 - dice_coef: 0.5430 - iou: 0.3736 - accuracy: 0.9638
# Epoch 8: val_iou did not improve from 0.09262
# 125/125 [==============================] - 44s 348ms/step - loss: 0.4570 - dice_coef: 0.5430 - iou: 0.3736 - accuracy: 0.9638 - val_loss: 0.8820 - val_dice_coef: 0.1181 - val_iou: 0.0628 - val_accuracy: 0.8844
# Epoch 9/500
# 125/125 [==============================] - ETA: 0s - loss: 0.4361 - dice_coef: 0.5639 - iou: 0.3937 - accuracy: 0.9684
# Epoch 9: val_iou did not improve from 0.09262
# 125/125 [==============================] - 43s 348ms/step - loss: 0.4361 - dice_coef: 0.5639 - iou: 0.3937 - accuracy: 0.9684 - val_loss: 0.8877 - val_dice_coef: 0.1124 - val_iou: 0.0596 - val_accuracy: 0.8844
# Epoch 10/500
# 125/125 [==============================] - ETA: 0s - loss: 0.4146 - dice_coef: 0.5854 - iou: 0.4149 - accuracy: 0.9720
# Epoch 10: val_iou did not improve from 0.09262
# 125/125 [==============================] - 43s 347ms/step - loss: 0.4146 - dice_coef: 0.5854 - iou: 0.4149 - accuracy: 0.9720 - val_loss: 0.8934 - val_dice_coef: 0.1067 - val_iou: 0.0564 - val_accuracy: 0.8844
# Epoch 11/500
# 125/125 [==============================] - ETA: 0s - loss: 0.3949 - dice_coef: 0.6051 - iou: 0.4350 - accuracy: 0.9741
# Epoch 11: val_iou did not improve from 0.09262
# 125/125 [==============================] - 43s 347ms/step - loss: 0.3949 - dice_coef: 0.6051 - iou: 0.4350 - accuracy: 0.9741 - val_loss: 0.8983 - val_dice_coef: 0.1018 - val_iou: 0.0536 - val_accuracy: 0.8844
# Epoch 12/500
# 125/125 [==============================] - ETA: 0s - loss: 0.3736 - dice_coef: 0.6264 - iou: 0.4571 - accuracy: 0.9767
# Epoch 12: val_iou did not improve from 0.09262
# 125/125 [==============================] - 43s 346ms/step - loss: 0.3736 - dice_coef: 0.6264 - iou: 0.4571 - accuracy: 0.9767 - val_loss: 0.9031 - val_dice_coef: 0.0970 - val_iou: 0.0510 - val_accuracy: 0.8844
# Epoch 13/500
# 125/125 [==============================] - ETA: 0s - loss: 0.3536 - dice_coef: 0.6464 - iou: 0.4786 - accuracy: 0.9788
# Epoch 13: val_iou did not improve from 0.09262
# 125/125 [==============================] - 44s 348ms/step - loss: 0.3536 - dice_coef: 0.6464 - iou: 0.4786 - accuracy: 0.9788 - val_loss: 0.9081 - val_dice_coef: 0.0920 - val_iou: 0.0482 - val_accuracy: 0.8844
# Epoch 14/500
# 125/125 [==============================] - ETA: 0s - loss: 0.3348 - dice_coef: 0.6652 - iou: 0.4994 - accuracy: 0.9798
# Epoch 14: val_iou did not improve from 0.09262
# 125/125 [==============================] - 43s 347ms/step - loss: 0.3348 - dice_coef: 0.6652 - iou: 0.4994 - accuracy: 0.9798 - val_loss: 0.9124 - val_dice_coef: 0.0877 - val_iou: 0.0459 - val_accuracy: 0.8844
# Epoch 15/500
# 125/125 [==============================] - ETA: 0s - loss: 0.3157 - dice_coef: 0.6843 - iou: 0.5211 - accuracy: 0.9813
# Epoch 15: val_iou did not improve from 0.09262
# 125/125 [==============================] - 43s 348ms/step - loss: 0.3157 - dice_coef: 0.6843 - iou: 0.5211 - accuracy: 0.9813 - val_loss: 0.9170 - val_dice_coef: 0.0831 - val_iou: 0.0433 - val_accuracy: 0.8844
# Epoch 16/500
# 125/125 [==============================] - ETA: 0s - loss: 0.2981 - dice_coef: 0.7019 - iou: 0.5418 - accuracy: 0.9823
# Epoch 16: val_iou did not improve from 0.09262
# 125/125 [==============================] - 44s 348ms/step - loss: 0.2981 - dice_coef: 0.7019 - iou: 0.5418 - accuracy: 0.9823 - val_loss: 0.9212 - val_dice_coef: 0.0789 - val_iou: 0.0411 - val_accuracy: 0.8844
# Epoch 17/500
# 125/125 [==============================] - ETA: 0s - loss: 0.2816 - dice_coef: 0.7184 - iou: 0.5618 - accuracy: 0.9828
# Epoch 17: val_iou did not improve from 0.09262
# 125/125 [==============================] - 43s 347ms/step - loss: 0.2816 - dice_coef: 0.7184 - iou: 0.5618 - accuracy: 0.9828 - val_loss: 0.9249 - val_dice_coef: 0.0751 - val_iou: 0.0390 - val_accuracy: 0.8844
# Epoch 18/500
# 125/125 [==============================] - ETA: 0s - loss: 0.2632 - dice_coef: 0.7368 - iou: 0.5842 - accuracy: 0.9836
# Epoch 18: val_iou did not improve from 0.09262
# 125/125 [==============================] - 44s 348ms/step - loss: 0.2632 - dice_coef: 0.7368 - iou: 0.5842 - accuracy: 0.9836 - val_loss: 0.9269 - val_dice_coef: 0.0731 - val_iou: 0.0380 - val_accuracy: 0.8844
# Epoch 19/500
# 125/125 [==============================] - ETA: 0s - loss: 0.2449 - dice_coef: 0.7551 - iou: 0.6077 - accuracy: 0.9844
# Epoch 19: val_iou did not improve from 0.09262
# 125/125 [==============================] - 43s 348ms/step - loss: 0.2449 - dice_coef: 0.7551 - iou: 0.6077 - accuracy: 0.9844 - val_loss: 0.9310 - val_dice_coef: 0.0691 - val_iou: 0.0358 - val_accuracy: 0.8844
# Epoch 20/500
# 125/125 [==============================] - ETA: 0s - loss: 0.2275 - dice_coef: 0.7725 - iou: 0.6302 - accuracy: 0.9853
# Epoch 20: val_iou did not improve from 0.09262
# 125/125 [==============================] - 43s 348ms/step - loss: 0.2275 - dice_coef: 0.7725 - iou: 0.6302 - accuracy: 0.9853 - val_loss: 0.9371 - val_dice_coef: 0.0629 - val_iou: 0.0325 - val_accuracy: 0.8844
# Epoch 21/500
# 125/125 [==============================] - ETA: 0s - loss: 0.2139 - dice_coef: 0.7861 - iou: 0.6487 - accuracy: 0.9858
# Epoch 21: val_iou did not improve from 0.09262
# 125/125 [==============================] - 44s 349ms/step - loss: 0.2139 - dice_coef: 0.7861 - iou: 0.6487 - accuracy: 0.9858 - val_loss: 0.9410 - val_dice_coef: 0.0590 - val_iou: 0.0304 - val_accuracy: 0.8844
# Epoch 22/500
# 125/125 [==============================] - ETA: 0s - loss: 0.1987 - dice_coef: 0.8013 - iou: 0.6693 - accuracy: 0.9865
# Epoch 22: val_iou did not improve from 0.09262
# 125/125 [==============================] - 44s 349ms/step - loss: 0.1987 - dice_coef: 0.8013 - iou: 0.6693 - accuracy: 0.9865 - val_loss: 0.9452 - val_dice_coef: 0.0548 - val_iou: 0.0282 - val_accuracy: 0.8844
# Epoch 23/500
# 125/125 [==============================] - ETA: 0s - loss: 0.1856 - dice_coef: 0.8144 - iou: 0.6877 - accuracy: 0.9870
# Epoch 23: val_iou did not improve from 0.09262
# 125/125 [==============================] - 44s 349ms/step - loss: 0.1856 - dice_coef: 0.8144 - iou: 0.6877 - accuracy: 0.9870 - val_loss: 0.9496 - val_dice_coef: 0.0504 - val_iou: 0.0258 - val_accuracy: 0.8844
# Epoch 24/500
# 125/125 [==============================] - ETA: 0s - loss: 0.1769 - dice_coef: 0.8231 - iou: 0.7004 - accuracy: 0.9867
# Epoch 24: val_iou did not improve from 0.09262
# 125/125 [==============================] - 44s 349ms/step - loss: 0.1769 - dice_coef: 0.8231 - iou: 0.7004 - accuracy: 0.9867 - val_loss: 0.9534 - val_dice_coef: 0.0466 - val_iou: 0.0239 - val_accuracy: 0.8844
# Epoch 25/500
# 125/125 [==============================] - ETA: 0s - loss: 0.1639 - dice_coef: 0.8361 - iou: 0.7189 - accuracy: 0.9875
# Epoch 25: val_iou did not improve from 0.09262
# 125/125 [==============================] - 44s 349ms/step - loss: 0.1639 - dice_coef: 0.8361 - iou: 0.7189 - accuracy: 0.9875 - val_loss: 0.9569 - val_dice_coef: 0.0431 - val_iou: 0.0220 - val_accuracy: 0.8844
# Epoch 26/500
# 125/125 [==============================] - ETA: 0s - loss: 0.1541 - dice_coef: 0.8459 - iou: 0.7338 - accuracy: 0.9880
# Epoch 26: val_iou did not improve from 0.09262
# 125/125 [==============================] - 43s 347ms/step - loss: 0.1541 - dice_coef: 0.8459 - iou: 0.7338 - accuracy: 0.9880 - val_loss: 0.9601 - val_dice_coef: 0.0400 - val_iou: 0.0204 - val_accuracy: 0.8844
# Epoch 27/500
# 125/125 [==============================] - ETA: 0s - loss: 0.1443 - dice_coef: 0.8557 - iou: 0.7484 - accuracy: 0.9884
# Epoch 27: val_iou did not improve from 0.09262
# 125/125 [==============================] - 44s 349ms/step - loss: 0.1443 - dice_coef: 0.8557 - iou: 0.7484 - accuracy: 0.9884 - val_loss: 0.9629 - val_dice_coef: 0.0371 - val_iou: 0.0189 - val_accuracy: 0.8844
# Epoch 28/500
# 125/125 [==============================] - ETA: 0s - loss: 0.1372 - dice_coef: 0.8628 - iou: 0.7594 - accuracy: 0.9884
# Epoch 28: val_iou did not improve from 0.09262
# 125/125 [==============================] - 44s 348ms/step - loss: 0.1372 - dice_coef: 0.8628 - iou: 0.7594 - accuracy: 0.9884 - val_loss: 0.9653 - val_dice_coef: 0.0347 - val_iou: 0.0177 - val_accuracy: 0.8844
# Epoch 29/500
# 125/125 [==============================] - ETA: 0s - loss: 0.1268 - dice_coef: 0.8732 - iou: 0.7753 - accuracy: 0.9891
# Epoch 29: val_iou did not improve from 0.09262
# 125/125 [==============================] - 44s 348ms/step - loss: 0.1268 - dice_coef: 0.8732 - iou: 0.7753 - accuracy: 0.9891 - val_loss: 0.9680 - val_dice_coef: 0.0320 - val_iou: 0.0163 - val_accuracy: 0.8844
# Epoch 30/500
# 125/125 [==============================] - ETA: 0s - loss: 0.1194 - dice_coef: 0.8806 - iou: 0.7871 - accuracy: 0.9894
# Epoch 30: val_iou did not improve from 0.09262
# 125/125 [==============================] - 43s 348ms/step - loss: 0.1194 - dice_coef: 0.8806 - iou: 0.7871 - accuracy: 0.9894 - val_loss: 0.9701 - val_dice_coef: 0.0299 - val_iou: 0.0152 - val_accuracy: 0.8844
# Epoch 31/500
# 125/125 [==============================] - ETA: 0s - loss: 0.1123 - dice_coef: 0.8877 - iou: 0.7984 - accuracy: 0.9898
# Epoch 31: val_iou did not improve from 0.09262
# 125/125 [==============================] - 44s 348ms/step - loss: 0.1123 - dice_coef: 0.8877 - iou: 0.7984 - accuracy: 0.9898 - val_loss: 0.9722 - val_dice_coef: 0.0278 - val_iou: 0.0141 - val_accuracy: 0.8844
# Epoch 32/500
# 125/125 [==============================] - ETA: 0s - loss: 0.1076 - dice_coef: 0.8924 - iou: 0.8062 - accuracy: 0.9897
# Epoch 32: val_iou did not improve from 0.09262
# 125/125 [==============================] - 44s 348ms/step - loss: 0.1076 - dice_coef: 0.8924 - iou: 0.8062 - accuracy: 0.9897 - val_loss: 0.9745 - val_dice_coef: 0.0255 - val_iou: 0.0129 - val_accuracy: 0.8844
# Epoch 33/500
# 125/125 [==============================] - ETA: 0s - loss: 0.1011 - dice_coef: 0.8989 - iou: 0.8168 - accuracy: 0.9901
# Epoch 33: val_iou did not improve from 0.09262
# 125/125 [==============================] - 43s 348ms/step - loss: 0.1011 - dice_coef: 0.8989 - iou: 0.8168 - accuracy: 0.9901 - val_loss: 0.9764 - val_dice_coef: 0.0236 - val_iou: 0.0119 - val_accuracy: 0.8844
# Epoch 34/500
# 125/125 [==============================] - ETA: 0s - loss: 0.0952 - dice_coef: 0.9048 - iou: 0.8265 - accuracy: 0.9903
# Epoch 34: val_iou did not improve from 0.09262
# 125/125 [==============================] - 43s 346ms/step - loss: 0.0952 - dice_coef: 0.9048 - iou: 0.8265 - accuracy: 0.9903 - val_loss: 0.9766 - val_dice_coef: 0.0235 - val_iou: 0.0119 - val_accuracy: 0.8844
# Epoch 35/500
# 125/125 [==============================] - ETA: 0s - loss: 0.0898 - dice_coef: 0.9102 - iou: 0.8354 - accuracy: 0.9905
# Epoch 35: val_iou did not improve from 0.09262
# 125/125 [==============================] - 44s 349ms/step - loss: 0.0898 - dice_coef: 0.9102 - iou: 0.8354 - accuracy: 0.9905 - val_loss: 0.9771 - val_dice_coef: 0.0230 - val_iou: 0.0116 - val_accuracy: 0.8844
# Epoch 36/500
# 125/125 [==============================] - ETA: 0s - loss: 0.0850 - dice_coef: 0.9150 - iou: 0.8436 - accuracy: 0.9906
# Epoch 36: val_iou did not improve from 0.09262
# 125/125 [==============================] - 43s 348ms/step - loss: 0.0850 - dice_coef: 0.9150 - iou: 0.8436 - accuracy: 0.9906 - val_loss: 0.9765 - val_dice_coef: 0.0235 - val_iou: 0.0119 - val_accuracy: 0.8844
# Epoch 37/500
# 125/125 [==============================] - ETA: 0s - loss: 0.0803 - dice_coef: 0.9197 - iou: 0.8516 - accuracy: 0.9909
# Epoch 37: val_iou did not improve from 0.09262
# 125/125 [==============================] - 43s 348ms/step - loss: 0.0803 - dice_coef: 0.9197 - iou: 0.8516 - accuracy: 0.9909 - val_loss: 0.9781 - val_dice_coef: 0.0219 - val_iou: 0.0111 - val_accuracy: 0.8844
# Epoch 38/500
# 125/125 [==============================] - ETA: 0s - loss: 0.0759 - dice_coef: 0.9241 - iou: 0.8592 - accuracy: 0.9912
# Epoch 38: val_iou did not improve from 0.09262
# 125/125 [==============================] - 44s 348ms/step - loss: 0.0759 - dice_coef: 0.9241 - iou: 0.8592 - accuracy: 0.9912 - val_loss: 0.9808 - val_dice_coef: 0.0192 - val_iou: 0.0097 - val_accuracy: 0.8844
# Epoch 39/500
# 125/125 [==============================] - ETA: 0s - loss: 0.0725 - dice_coef: 0.9275 - iou: 0.8651 - accuracy: 0.9914
# Epoch 39: val_iou did not improve from 0.09262
# 125/125 [==============================] - 44s 348ms/step - loss: 0.0725 - dice_coef: 0.9275 - iou: 0.8651 - accuracy: 0.9914 - val_loss: 0.9827 - val_dice_coef: 0.0173 - val_iou: 0.0087 - val_accuracy: 0.8844
# Epoch 40/500
# 125/125 [==============================] - ETA: 0s - loss: 0.0695 - dice_coef: 0.9305 - iou: 0.8703 - accuracy: 0.9915
# Epoch 40: val_iou did not improve from 0.09262
# 125/125 [==============================] - 44s 349ms/step - loss: 0.0695 - dice_coef: 0.9305 - iou: 0.8703 - accuracy: 0.9915 - val_loss: 0.9842 - val_dice_coef: 0.0158 - val_iou: 0.0080 - val_accuracy: 0.8844
# Epoch 41/500
# 125/125 [==============================] - ETA: 0s - loss: 0.0663 - dice_coef: 0.9337 - iou: 0.8758 - accuracy: 0.9916
# Epoch 41: val_iou did not improve from 0.09262
# 125/125 [==============================] - 43s 348ms/step - loss: 0.0663 - dice_coef: 0.9337 - iou: 0.8758 - accuracy: 0.9916 - val_loss: 0.9856 - val_dice_coef: 0.0144 - val_iou: 0.0072 - val_accuracy: 0.8844
# Epoch 42/500
# 125/125 [==============================] - ETA: 0s - loss: 0.0628 - dice_coef: 0.9372 - iou: 0.8819 - accuracy: 0.9919
# Epoch 42: val_iou did not improve from 0.09262
# 125/125 [==============================] - 44s 348ms/step - loss: 0.0628 - dice_coef: 0.9372 - iou: 0.8819 - accuracy: 0.9919 - val_loss: 0.9865 - val_dice_coef: 0.0136 - val_iou: 0.0068 - val_accuracy: 0.8844
# Epoch 43/500
# 125/125 [==============================] - ETA: 0s - loss: 0.0608 - dice_coef: 0.9392 - iou: 0.8856 - accuracy: 0.9920
# Epoch 43: val_iou did not improve from 0.09262
# 125/125 [==============================] - 43s 348ms/step - loss: 0.0608 - dice_coef: 0.9392 - iou: 0.8856 - accuracy: 0.9920 - val_loss: 0.9877 - val_dice_coef: 0.0123 - val_iou: 0.0062 - val_accuracy: 0.8844
# Epoch 44/500
# 125/125 [==============================] - ETA: 0s - loss: 0.0619 - dice_coef: 0.9381 - iou: 0.8836 - accuracy: 0.9913
# Epoch 44: val_iou did not improve from 0.09262
# 125/125 [==============================] - 43s 348ms/step - loss: 0.0619 - dice_coef: 0.9381 - iou: 0.8836 - accuracy: 0.9913 - val_loss: 0.9893 - val_dice_coef: 0.0107 - val_iou: 0.0054 - val_accuracy: 0.8844
# Epoch 45/500
# 125/125 [==============================] - ETA: 0s - loss: 0.0572 - dice_coef: 0.9428 - iou: 0.8918 - accuracy: 0.9920
# Epoch 45: val_iou did not improve from 0.09262
# 125/125 [==============================] - 43s 347ms/step - loss: 0.0572 - dice_coef: 0.9428 - iou: 0.8918 - accuracy: 0.9920 - val_loss: 0.9897 - val_dice_coef: 0.0103 - val_iou: 0.0052 - val_accuracy: 0.8844
# Epoch 46/500
# 125/125 [==============================] - ETA: 0s - loss: 0.0541 - dice_coef: 0.9459 - iou: 0.8974 - accuracy: 0.9924
# Epoch 46: val_iou did not improve from 0.09262
# 125/125 [==============================] - 43s 348ms/step - loss: 0.0541 - dice_coef: 0.9459 - iou: 0.8974 - accuracy: 0.9924 - val_loss: 0.9900 - val_dice_coef: 0.0100 - val_iou: 0.0050 - val_accuracy: 0.8844
# Epoch 47/500
# 125/125 [==============================] - ETA: 0s - loss: 0.0527 - dice_coef: 0.9473 - iou: 0.8999 - accuracy: 0.9925
# Epoch 47: val_iou did not improve from 0.09262
# 125/125 [==============================] - 44s 349ms/step - loss: 0.0527 - dice_coef: 0.9473 - iou: 0.8999 - accuracy: 0.9925 - val_loss: 0.9907 - val_dice_coef: 0.0093 - val_iou: 0.0047 - val_accuracy: 0.8844
# Epoch 48/500
# 125/125 [==============================] - ETA: 0s - loss: 0.0506 - dice_coef: 0.9494 - iou: 0.9037 - accuracy: 0.9926
# Epoch 48: val_iou did not improve from 0.09262
# 125/125 [==============================] - 43s 348ms/step - loss: 0.0506 - dice_coef: 0.9494 - iou: 0.9037 - accuracy: 0.9926 - val_loss: 0.9917 - val_dice_coef: 0.0083 - val_iou: 0.0042 - val_accuracy: 0.8844
# Epoch 49/500
# 125/125 [==============================] - ETA: 0s - loss: 0.0484 - dice_coef: 0.9516 - iou: 0.9077 - accuracy: 0.9928
# Epoch 49: val_iou did not improve from 0.09262
# 125/125 [==============================] - 43s 347ms/step - loss: 0.0484 - dice_coef: 0.9516 - iou: 0.9077 - accuracy: 0.9928 - val_loss: 0.9923 - val_dice_coef: 0.0077 - val_iou: 0.0039 - val_accuracy: 0.8844
# Epoch 50/500
# 125/125 [==============================] - ETA: 0s - loss: 0.0468 - dice_coef: 0.9532 - iou: 0.9107 - accuracy: 0.9929
# Epoch 50: val_iou did not improve from 0.09262
# 125/125 [==============================] - 44s 349ms/step - loss: 0.0468 - dice_coef: 0.9532 - iou: 0.9107 - accuracy: 0.9929 - val_loss: 0.9900 - val_dice_coef: 0.0100 - val_iou: 0.0051 - val_accuracy: 0.8845
# Epoch 51/500
# 125/125 [==============================] - ETA: 0s - loss: 0.0457 - dice_coef: 0.9543 - iou: 0.9127 - accuracy: 0.9930
# Epoch 51: val_iou did not improve from 0.09262
# 125/125 [==============================] - 44s 349ms/step - loss: 0.0457 - dice_coef: 0.9543 - iou: 0.9127 - accuracy: 0.9930 - val_loss: 0.9903 - val_dice_coef: 0.0096 - val_iou: 0.0049 - val_accuracy: 0.8845
# Epoch 52/500
# 125/125 [==============================] - ETA: 0s - loss: 0.0445 - dice_coef: 0.9555 - iou: 0.9149 - accuracy: 0.9931
# Epoch 52: val_iou did not improve from 0.09262
# 125/125 [==============================] - 44s 349ms/step - loss: 0.0445 - dice_coef: 0.9555 - iou: 0.9149 - accuracy: 0.9931 - val_loss: 0.9705 - val_dice_coef: 0.0299 - val_iou: 0.0155 - val_accuracy: 0.8856
# Epoch 53/500
# 125/125 [==============================] - ETA: 0s - loss: 0.0431 - dice_coef: 0.9569 - iou: 0.9174 - accuracy: 0.9931
# Epoch 53: val_iou improved from 0.09262 to 0.14546, saving model to /content/drive/MyDrive/Colab Notebooks/Checkpoints_main/pffline_mobv2link_cbam_lasttry/cp.ckpt
# 125/125 [==============================] - 44s 353ms/step - loss: 0.0431 - dice_coef: 0.9569 - iou: 0.9174 - accuracy: 0.9931 - val_loss: 0.7656 - val_dice_coef: 0.2376 - val_iou: 0.1455 - val_accuracy: 0.8996
# Epoch 54/500
# 125/125 [==============================] - ETA: 0s - loss: 0.0416 - dice_coef: 0.9584 - iou: 0.9201 - accuracy: 0.9933
# Epoch 54: val_iou improved from 0.14546 to 0.28953, saving model to /content/drive/MyDrive/Colab Notebooks/Checkpoints_main/pffline_mobv2link_cbam_lasttry/cp.ckpt
# 125/125 [==============================] - 44s 352ms/step - loss: 0.0416 - dice_coef: 0.9584 - iou: 0.9201 - accuracy: 0.9933 - val_loss: 0.5725 - val_dice_coef: 0.4302 - val_iou: 0.2895 - val_accuracy: 0.9153
# Epoch 55/500
# 125/125 [==============================] - ETA: 0s - loss: 0.0401 - dice_coef: 0.9599 - iou: 0.9229 - accuracy: 0.9934
# Epoch 55: val_iou improved from 0.28953 to 0.30775, saving model to /content/drive/MyDrive/Colab Notebooks/Checkpoints_main/pffline_mobv2link_cbam_lasttry/cp.ckpt
# 125/125 [==============================] - 44s 352ms/step - loss: 0.0401 - dice_coef: 0.9599 - iou: 0.9229 - accuracy: 0.9934 - val_loss: 0.5531 - val_dice_coef: 0.4494 - val_iou: 0.3078 - val_accuracy: 0.9182
# Epoch 56/500
# 125/125 [==============================] - ETA: 0s - loss: 0.0391 - dice_coef: 0.9609 - iou: 0.9247 - accuracy: 0.9935
# Epoch 56: val_iou improved from 0.30775 to 0.41201, saving model to /content/drive/MyDrive/Colab Notebooks/Checkpoints_main/pffline_mobv2link_cbam_lasttry/cp.ckpt
# 125/125 [==============================] - 44s 352ms/step - loss: 0.0391 - dice_coef: 0.9609 - iou: 0.9247 - accuracy: 0.9935 - val_loss: 0.4373 - val_dice_coef: 0.5647 - val_iou: 0.4120 - val_accuracy: 0.9291
# Epoch 57/500
# 125/125 [==============================] - ETA: 0s - loss: 0.0381 - dice_coef: 0.9619 - iou: 0.9266 - accuracy: 0.9935
# Epoch 57: val_iou improved from 0.41201 to 0.43142, saving model to /content/drive/MyDrive/Colab Notebooks/Checkpoints_main/pffline_mobv2link_cbam_lasttry/cp.ckpt
# 125/125 [==============================] - 44s 353ms/step - loss: 0.0381 - dice_coef: 0.9619 - iou: 0.9266 - accuracy: 0.9935 - val_loss: 0.4171 - val_dice_coef: 0.5847 - val_iou: 0.4314 - val_accuracy: 0.9313
# Epoch 58/500
# 125/125 [==============================] - ETA: 0s - loss: 0.0373 - dice_coef: 0.9627 - iou: 0.9282 - accuracy: 0.9936
# Epoch 58: val_iou improved from 0.43142 to 0.53227, saving model to /content/drive/MyDrive/Colab Notebooks/Checkpoints_main/pffline_mobv2link_cbam_lasttry/cp.ckpt
# 125/125 [==============================] - 44s 352ms/step - loss: 0.0373 - dice_coef: 0.9627 - iou: 0.9282 - accuracy: 0.9936 - val_loss: 0.3246 - val_dice_coef: 0.6771 - val_iou: 0.5323 - val_accuracy: 0.9443
# Epoch 59/500
# 125/125 [==============================] - ETA: 0s - loss: 0.0367 - dice_coef: 0.9633 - iou: 0.9292 - accuracy: 0.9936
# Epoch 59: val_iou improved from 0.53227 to 0.54103, saving model to /content/drive/MyDrive/Colab Notebooks/Checkpoints_main/pffline_mobv2link_cbam_lasttry/cp.ckpt
# 125/125 [==============================] - 44s 353ms/step - loss: 0.0367 - dice_coef: 0.9633 - iou: 0.9292 - accuracy: 0.9936 - val_loss: 0.3148 - val_dice_coef: 0.6866 - val_iou: 0.5410 - val_accuracy: 0.9445
# Epoch 60/500
# 125/125 [==============================] - ETA: 0s - loss: 0.0355 - dice_coef: 0.9645 - iou: 0.9314 - accuracy: 0.9938
# Epoch 60: val_iou improved from 0.54103 to 0.61942, saving model to /content/drive/MyDrive/Colab Notebooks/Checkpoints_main/pffline_mobv2link_cbam_lasttry/cp.ckpt
# 125/125 [==============================] - 44s 353ms/step - loss: 0.0355 - dice_coef: 0.9645 - iou: 0.9314 - accuracy: 0.9938 - val_loss: 0.2492 - val_dice_coef: 0.7521 - val_iou: 0.6194 - val_accuracy: 0.9521
# Epoch 61/500
# 125/125 [==============================] - ETA: 0s - loss: 0.0350 - dice_coef: 0.9650 - iou: 0.9325 - accuracy: 0.9938
# Epoch 61: val_iou did not improve from 0.61942
# 125/125 [==============================] - 44s 349ms/step - loss: 0.0350 - dice_coef: 0.9650 - iou: 0.9325 - accuracy: 0.9938 - val_loss: 0.3000 - val_dice_coef: 0.7016 - val_iou: 0.5607 - val_accuracy: 0.9463
# Epoch 62/500
# 125/125 [==============================] - ETA: 0s - loss: 0.0338 - dice_coef: 0.9662 - iou: 0.9347 - accuracy: 0.9939
# Epoch 62: val_iou improved from 0.61942 to 0.62856, saving model to /content/drive/MyDrive/Colab Notebooks/Checkpoints_main/pffline_mobv2link_cbam_lasttry/cp.ckpt
# 125/125 [==============================] - 44s 351ms/step - loss: 0.0338 - dice_coef: 0.9662 - iou: 0.9347 - accuracy: 0.9939 - val_loss: 0.2420 - val_dice_coef: 0.7591 - val_iou: 0.6286 - val_accuracy: 0.9526
# Epoch 63/500
# 125/125 [==============================] - ETA: 0s - loss: 0.0332 - dice_coef: 0.9668 - iou: 0.9358 - accuracy: 0.9940
# Epoch 63: val_iou did not improve from 0.62856
# 125/125 [==============================] - 44s 349ms/step - loss: 0.0332 - dice_coef: 0.9668 - iou: 0.9358 - accuracy: 0.9940 - val_loss: 0.2475 - val_dice_coef: 0.7537 - val_iou: 0.6217 - val_accuracy: 0.9530
# Epoch 64/500
# 125/125 [==============================] - ETA: 0s - loss: 0.0324 - dice_coef: 0.9676 - iou: 0.9372 - accuracy: 0.9940
# Epoch 64: val_iou did not improve from 0.62856
# 125/125 [==============================] - 44s 349ms/step - loss: 0.0324 - dice_coef: 0.9676 - iou: 0.9372 - accuracy: 0.9940 - val_loss: 0.2431 - val_dice_coef: 0.7580 - val_iou: 0.6279 - val_accuracy: 0.9524
# Epoch 65/500
# 125/125 [==============================] - ETA: 0s - loss: 0.0319 - dice_coef: 0.9681 - iou: 0.9382 - accuracy: 0.9941
# Epoch 65: val_iou did not improve from 0.62856
# 125/125 [==============================] - 43s 347ms/step - loss: 0.0319 - dice_coef: 0.9681 - iou: 0.9382 - accuracy: 0.9941 - val_loss: 0.2449 - val_dice_coef: 0.7563 - val_iou: 0.6253 - val_accuracy: 0.9519
# Epoch 66/500
# 125/125 [==============================] - ETA: 0s - loss: 0.0312 - dice_coef: 0.9688 - iou: 0.9395 - accuracy: 0.9942
# Epoch 66: val_iou improved from 0.62856 to 0.65295, saving model to /content/drive/MyDrive/Colab Notebooks/Checkpoints_main/pffline_mobv2link_cbam_lasttry/cp.ckpt
# 125/125 [==============================] - 44s 352ms/step - loss: 0.0312 - dice_coef: 0.9688 - iou: 0.9395 - accuracy: 0.9942 - val_loss: 0.2227 - val_dice_coef: 0.7783 - val_iou: 0.6529 - val_accuracy: 0.9544
# Epoch 67/500
# 125/125 [==============================] - ETA: 0s - loss: 0.0307 - dice_coef: 0.9693 - iou: 0.9404 - accuracy: 0.9942
# Epoch 67: val_iou improved from 0.65295 to 0.66211, saving model to /content/drive/MyDrive/Colab Notebooks/Checkpoints_main/pffline_mobv2link_cbam_lasttry/cp.ckpt
# 125/125 [==============================] - 44s 354ms/step - loss: 0.0307 - dice_coef: 0.9693 - iou: 0.9404 - accuracy: 0.9942 - val_loss: 0.2158 - val_dice_coef: 0.7852 - val_iou: 0.6621 - val_accuracy: 0.9553
# Epoch 68/500
# 125/125 [==============================] - ETA: 0s - loss: 0.0299 - dice_coef: 0.9701 - iou: 0.9419 - accuracy: 0.9943
# Epoch 68: val_iou did not improve from 0.66211
# 125/125 [==============================] - 44s 349ms/step - loss: 0.0299 - dice_coef: 0.9701 - iou: 0.9419 - accuracy: 0.9943 - val_loss: 0.2245 - val_dice_coef: 0.7764 - val_iou: 0.6512 - val_accuracy: 0.9559
# Epoch 69/500
# 125/125 [==============================] - ETA: 0s - loss: 0.0296 - dice_coef: 0.9704 - iou: 0.9425 - accuracy: 0.9943
# Epoch 69: val_iou did not improve from 0.66211
# 125/125 [==============================] - 44s 349ms/step - loss: 0.0296 - dice_coef: 0.9704 - iou: 0.9425 - accuracy: 0.9943 - val_loss: 0.2169 - val_dice_coef: 0.7841 - val_iou: 0.6596 - val_accuracy: 0.9556
# Epoch 70/500
# 125/125 [==============================] - ETA: 0s - loss: 0.0291 - dice_coef: 0.9709 - iou: 0.9435 - accuracy: 0.9944
# Epoch 70: val_iou improved from 0.66211 to 0.66509, saving model to /content/drive/MyDrive/Colab Notebooks/Checkpoints_main/pffline_mobv2link_cbam_lasttry/cp.ckpt
# 125/125 [==============================] - 44s 352ms/step - loss: 0.0291 - dice_coef: 0.9709 - iou: 0.9435 - accuracy: 0.9944 - val_loss: 0.2128 - val_dice_coef: 0.7882 - val_iou: 0.6651 - val_accuracy: 0.9562
# Epoch 71/500
# 125/125 [==============================] - ETA: 0s - loss: 0.0287 - dice_coef: 0.9713 - iou: 0.9442 - accuracy: 0.9944
# Epoch 71: val_iou did not improve from 0.66509
# 125/125 [==============================] - 44s 349ms/step - loss: 0.0287 - dice_coef: 0.9713 - iou: 0.9442 - accuracy: 0.9944 - val_loss: 0.2230 - val_dice_coef: 0.7780 - val_iou: 0.6531 - val_accuracy: 0.9534
# Epoch 72/500
# 125/125 [==============================] - ETA: 0s - loss: 0.0281 - dice_coef: 0.9719 - iou: 0.9454 - accuracy: 0.9945
# Epoch 72: val_iou did not improve from 0.66509
# 125/125 [==============================] - 44s 349ms/step - loss: 0.0281 - dice_coef: 0.9719 - iou: 0.9454 - accuracy: 0.9945 - val_loss: 0.2190 - val_dice_coef: 0.7820 - val_iou: 0.6568 - val_accuracy: 0.9547
# Epoch 73/500
# 125/125 [==============================] - ETA: 0s - loss: 0.0279 - dice_coef: 0.9721 - iou: 0.9457 - accuracy: 0.9945
# Epoch 73: val_iou improved from 0.66509 to 0.66838, saving model to /content/drive/MyDrive/Colab Notebooks/Checkpoints_main/pffline_mobv2link_cbam_lasttry/cp.ckpt
# 125/125 [==============================] - 44s 353ms/step - loss: 0.0279 - dice_coef: 0.9721 - iou: 0.9457 - accuracy: 0.9945 - val_loss: 0.2115 - val_dice_coef: 0.7894 - val_iou: 0.6684 - val_accuracy: 0.9563
# Epoch 74/500
# 125/125 [==============================] - ETA: 0s - loss: 0.0277 - dice_coef: 0.9723 - iou: 0.9462 - accuracy: 0.9945
# Epoch 74: val_iou improved from 0.66838 to 0.67928, saving model to /content/drive/MyDrive/Colab Notebooks/Checkpoints_main/pffline_mobv2link_cbam_lasttry/cp.ckpt
# 125/125 [==============================] - 44s 353ms/step - loss: 0.0277 - dice_coef: 0.9723 - iou: 0.9462 - accuracy: 0.9945 - val_loss: 0.2038 - val_dice_coef: 0.7971 - val_iou: 0.6793 - val_accuracy: 0.9545
# Epoch 75/500
# 125/125 [==============================] - ETA: 0s - loss: 0.0273 - dice_coef: 0.9727 - iou: 0.9469 - accuracy: 0.9945
# Epoch 75: val_iou improved from 0.67928 to 0.68237, saving model to /content/drive/MyDrive/Colab Notebooks/Checkpoints_main/pffline_mobv2link_cbam_lasttry/cp.ckpt
# 125/125 [==============================] - 44s 353ms/step - loss: 0.0273 - dice_coef: 0.9727 - iou: 0.9469 - accuracy: 0.9945 - val_loss: 0.2004 - val_dice_coef: 0.8005 - val_iou: 0.6824 - val_accuracy: 0.9567
# Epoch 76/500
# 125/125 [==============================] - ETA: 0s - loss: 0.0267 - dice_coef: 0.9733 - iou: 0.9480 - accuracy: 0.9946
# Epoch 76: val_iou did not improve from 0.68237
# 125/125 [==============================] - 44s 348ms/step - loss: 0.0267 - dice_coef: 0.9733 - iou: 0.9480 - accuracy: 0.9946 - val_loss: 0.2038 - val_dice_coef: 0.7970 - val_iou: 0.6789 - val_accuracy: 0.9566
# Epoch 77/500
# 125/125 [==============================] - ETA: 0s - loss: 0.0261 - dice_coef: 0.9739 - iou: 0.9491 - accuracy: 0.9947
# Epoch 77: val_iou did not improve from 0.68237
# 125/125 [==============================] - 44s 349ms/step - loss: 0.0261 - dice_coef: 0.9739 - iou: 0.9491 - accuracy: 0.9947 - val_loss: 0.2109 - val_dice_coef: 0.7901 - val_iou: 0.6712 - val_accuracy: 0.9544
# Epoch 78/500
# 125/125 [==============================] - ETA: 0s - loss: 0.0263 - dice_coef: 0.9737 - iou: 0.9487 - accuracy: 0.9946
# Epoch 78: val_iou did not improve from 0.68237
# 125/125 [==============================] - 43s 348ms/step - loss: 0.0263 - dice_coef: 0.9737 - iou: 0.9487 - accuracy: 0.9946 - val_loss: 0.2104 - val_dice_coef: 0.7906 - val_iou: 0.6704 - val_accuracy: 0.9538
# Epoch 79/500
# 125/125 [==============================] - ETA: 0s - loss: 0.0257 - dice_coef: 0.9743 - iou: 0.9500 - accuracy: 0.9947
# Epoch 79: val_iou did not improve from 0.68237
# 125/125 [==============================] - 44s 349ms/step - loss: 0.0257 - dice_coef: 0.9743 - iou: 0.9500 - accuracy: 0.9947 - val_loss: 0.2086 - val_dice_coef: 0.7923 - val_iou: 0.6722 - val_accuracy: 0.9548
# Epoch 80/500
# 125/125 [==============================] - ETA: 0s - loss: 0.0255 - dice_coef: 0.9745 - iou: 0.9503 - accuracy: 0.9947
# Epoch 80: val_iou improved from 0.68237 to 0.68780, saving model to /content/drive/MyDrive/Colab Notebooks/Checkpoints_main/pffline_mobv2link_cbam_lasttry/cp.ckpt
# 125/125 [==============================] - 44s 353ms/step - loss: 0.0255 - dice_coef: 0.9745 - iou: 0.9503 - accuracy: 0.9947 - val_loss: 0.1978 - val_dice_coef: 0.8030 - val_iou: 0.6878 - val_accuracy: 0.9559
# Epoch 81/500
# 125/125 [==============================] - ETA: 0s - loss: 0.0253 - dice_coef: 0.9747 - iou: 0.9506 - accuracy: 0.9948
# Epoch 81: val_iou did not improve from 0.68780
# 125/125 [==============================] - 43s 348ms/step - loss: 0.0253 - dice_coef: 0.9747 - iou: 0.9506 - accuracy: 0.9948 - val_loss: 0.2185 - val_dice_coef: 0.7824 - val_iou: 0.6589 - val_accuracy: 0.9542
# Epoch 82/500
# 125/125 [==============================] - ETA: 0s - loss: 0.0250 - dice_coef: 0.9750 - iou: 0.9512 - accuracy: 0.9948
# Epoch 82: val_iou did not improve from 0.68780
# 125/125 [==============================] - 43s 347ms/step - loss: 0.0250 - dice_coef: 0.9750 - iou: 0.9512 - accuracy: 0.9948 - val_loss: 0.2008 - val_dice_coef: 0.8000 - val_iou: 0.6834 - val_accuracy: 0.9567
# Epoch 83/500
# 125/125 [==============================] - ETA: 0s - loss: 0.0244 - dice_coef: 0.9756 - iou: 0.9524 - accuracy: 0.9949
# Epoch 83: val_iou did not improve from 0.68780
# 125/125 [==============================] - 43s 346ms/step - loss: 0.0244 - dice_coef: 0.9756 - iou: 0.9524 - accuracy: 0.9949 - val_loss: 0.2120 - val_dice_coef: 0.7889 - val_iou: 0.6671 - val_accuracy: 0.9559
# Epoch 84/500
# 125/125 [==============================] - ETA: 0s - loss: 0.0242 - dice_coef: 0.9758 - iou: 0.9527 - accuracy: 0.9949
# Epoch 84: val_iou did not improve from 0.68780
# 125/125 [==============================] - 43s 347ms/step - loss: 0.0242 - dice_coef: 0.9758 - iou: 0.9527 - accuracy: 0.9949 - val_loss: 0.2060 - val_dice_coef: 0.7948 - val_iou: 0.6760 - val_accuracy: 0.9552
# Epoch 85/500
# 125/125 [==============================] - ETA: 0s - loss: 0.0241 - dice_coef: 0.9759 - iou: 0.9530 - accuracy: 0.9950
# Epoch 85: val_iou did not improve from 0.68780
# 125/125 [==============================] - 43s 348ms/step - loss: 0.0241 - dice_coef: 0.9759 - iou: 0.9530 - accuracy: 0.9950 - val_loss: 0.2093 - val_dice_coef: 0.7917 - val_iou: 0.6727 - val_accuracy: 0.9552
# Epoch 86/500
# 125/125 [==============================] - ETA: 0s - loss: 0.0237 - dice_coef: 0.9763 - iou: 0.9537 - accuracy: 0.9950
# Epoch 86: val_iou did not improve from 0.68780
# 125/125 [==============================] - 43s 348ms/step - loss: 0.0237 - dice_coef: 0.9763 - iou: 0.9537 - accuracy: 0.9950 - val_loss: 0.2036 - val_dice_coef: 0.7973 - val_iou: 0.6813 - val_accuracy: 0.9550
# Epoch 87/500
# 125/125 [==============================] - ETA: 0s - loss: 0.0237 - dice_coef: 0.9763 - iou: 0.9537 - accuracy: 0.9950
# Epoch 87: val_iou did not improve from 0.68780
# 125/125 [==============================] - 43s 348ms/step - loss: 0.0237 - dice_coef: 0.9763 - iou: 0.9537 - accuracy: 0.9950 - val_loss: 0.2150 - val_dice_coef: 0.7859 - val_iou: 0.6650 - val_accuracy: 0.9541
# Epoch 88/500
# 125/125 [==============================] - ETA: 0s - loss: 0.0240 - dice_coef: 0.9760 - iou: 0.9532 - accuracy: 0.9949
# Epoch 88: val_iou did not improve from 0.68780
# 125/125 [==============================] - 44s 349ms/step - loss: 0.0240 - dice_coef: 0.9760 - iou: 0.9532 - accuracy: 0.9949 - val_loss: 0.2119 - val_dice_coef: 0.7891 - val_iou: 0.6696 - val_accuracy: 0.9525
# Epoch 89/500
# 125/125 [==============================] - ETA: 0s - loss: 0.0236 - dice_coef: 0.9764 - iou: 0.9539 - accuracy: 0.9950
# Epoch 89: val_iou did not improve from 0.68780
# 125/125 [==============================] - 44s 349ms/step - loss: 0.0236 - dice_coef: 0.9764 - iou: 0.9539 - accuracy: 0.9950 - val_loss: 0.1998 - val_dice_coef: 0.8010 - val_iou: 0.6846 - val_accuracy: 0.9560
# Epoch 90/500
# 125/125 [==============================] - ETA: 0s - loss: 0.0231 - dice_coef: 0.9769 - iou: 0.9549 - accuracy: 0.9951
# Epoch 90: val_iou did not improve from 0.68780
# 125/125 [==============================] - 43s 348ms/step - loss: 0.0231 - dice_coef: 0.9769 - iou: 0.9549 - accuracy: 0.9951 - val_loss: 0.2197 - val_dice_coef: 0.7812 - val_iou: 0.6584 - val_accuracy: 0.9525
# Epoch 91/500
# 125/125 [==============================] - ETA: 0s - loss: 0.0228 - dice_coef: 0.9772 - iou: 0.9555 - accuracy: 0.9951
# Epoch 91: val_iou did not improve from 0.68780
# 125/125 [==============================] - 43s 347ms/step - loss: 0.0228 - dice_coef: 0.9772 - iou: 0.9555 - accuracy: 0.9951 - val_loss: 0.2121 - val_dice_coef: 0.7887 - val_iou: 0.6685 - val_accuracy: 0.9555
# Epoch 92/500
# 125/125 [==============================] - ETA: 0s - loss: 0.0225 - dice_coef: 0.9775 - iou: 0.9559 - accuracy: 0.9952
# Epoch 92: val_iou improved from 0.68780 to 0.68935, saving model to /content/drive/MyDrive/Colab Notebooks/Checkpoints_main/pffline_mobv2link_cbam_lasttry/cp.ckpt
# 125/125 [==============================] - 44s 354ms/step - loss: 0.0225 - dice_coef: 0.9775 - iou: 0.9559 - accuracy: 0.9952 - val_loss: 0.1969 - val_dice_coef: 0.8040 - val_iou: 0.6893 - val_accuracy: 0.9553
# Epoch 93/500
# 125/125 [==============================] - ETA: 0s - loss: 0.0227 - dice_coef: 0.9773 - iou: 0.9556 - accuracy: 0.9951
# Epoch 93: val_iou did not improve from 0.68935
# 125/125 [==============================] - 44s 349ms/step - loss: 0.0227 - dice_coef: 0.9773 - iou: 0.9556 - accuracy: 0.9951 - val_loss: 0.2021 - val_dice_coef: 0.7987 - val_iou: 0.6835 - val_accuracy: 0.9522
# Epoch 94/500
# 125/125 [==============================] - ETA: 0s - loss: 0.0229 - dice_coef: 0.9771 - iou: 0.9552 - accuracy: 0.9951
# Epoch 94: val_iou did not improve from 0.68935
# 125/125 [==============================] - 44s 350ms/step - loss: 0.0229 - dice_coef: 0.9771 - iou: 0.9552 - accuracy: 0.9951 - val_loss: 0.2047 - val_dice_coef: 0.7960 - val_iou: 0.6746 - val_accuracy: 0.9569
# Epoch 95/500
# 125/125 [==============================] - ETA: 0s - loss: 0.0243 - dice_coef: 0.9757 - iou: 0.9526 - accuracy: 0.9947
# Epoch 95: val_iou did not improve from 0.68935
# 125/125 [==============================] - 43s 348ms/step - loss: 0.0243 - dice_coef: 0.9757 - iou: 0.9526 - accuracy: 0.9947 - val_loss: 0.1980 - val_dice_coef: 0.8029 - val_iou: 0.6870 - val_accuracy: 0.9527
# Epoch 96/500
# 125/125 [==============================] - ETA: 0s - loss: 0.0231 - dice_coef: 0.9769 - iou: 0.9548 - accuracy: 0.9950
# Epoch 96: val_iou did not improve from 0.68935
# 125/125 [==============================] - 44s 349ms/step - loss: 0.0231 - dice_coef: 0.9769 - iou: 0.9548 - accuracy: 0.9950 - val_loss: 0.2007 - val_dice_coef: 0.8002 - val_iou: 0.6850 - val_accuracy: 0.9536
# Epoch 97/500
# 125/125 [==============================] - ETA: 0s - loss: 0.0222 - dice_coef: 0.9778 - iou: 0.9566 - accuracy: 0.9952
# Epoch 97: val_iou improved from 0.68935 to 0.69664, saving model to /content/drive/MyDrive/Colab Notebooks/Checkpoints_main/pffline_mobv2link_cbam_lasttry/cp.ckpt
# 125/125 [==============================] - 44s 353ms/step - loss: 0.0222 - dice_coef: 0.9778 - iou: 0.9566 - accuracy: 0.9952 - val_loss: 0.1913 - val_dice_coef: 0.8095 - val_iou: 0.6966 - val_accuracy: 0.9565
# Epoch 98/500
# 125/125 [==============================] - ETA: 0s - loss: 0.0219 - dice_coef: 0.9781 - iou: 0.9571 - accuracy: 0.9952
# Epoch 98: val_iou did not improve from 0.69664
# 125/125 [==============================] - 44s 349ms/step - loss: 0.0219 - dice_coef: 0.9781 - iou: 0.9571 - accuracy: 0.9952 - val_loss: 0.1971 - val_dice_coef: 0.8037 - val_iou: 0.6878 - val_accuracy: 0.9561
# Epoch 99/500
# 125/125 [==============================] - ETA: 0s - loss: 0.0213 - dice_coef: 0.9787 - iou: 0.9584 - accuracy: 0.9954
# Epoch 99: val_iou did not improve from 0.69664
# 125/125 [==============================] - 44s 350ms/step - loss: 0.0213 - dice_coef: 0.9787 - iou: 0.9584 - accuracy: 0.9954 - val_loss: 0.1992 - val_dice_coef: 0.8015 - val_iou: 0.6851 - val_accuracy: 0.9543
# Epoch 100/500
# 125/125 [==============================] - ETA: 0s - loss: 0.0208 - dice_coef: 0.9792 - iou: 0.9593 - accuracy: 0.9955
# Epoch 100: val_iou improved from 0.69664 to 0.69730, saving model to /content/drive/MyDrive/Colab Notebooks/Checkpoints_main/pffline_mobv2link_cbam_lasttry/cp.ckpt
# 125/125 [==============================] - 44s 354ms/step - loss: 0.0208 - dice_coef: 0.9792 - iou: 0.9593 - accuracy: 0.9955 - val_loss: 0.1906 - val_dice_coef: 0.8103 - val_iou: 0.6973 - val_accuracy: 0.9558
# Epoch 101/500
# 125/125 [==============================] - ETA: 0s - loss: 0.0207 - dice_coef: 0.9793 - iou: 0.9594 - accuracy: 0.9955
# Epoch 101: val_iou did not improve from 0.69730
# 125/125 [==============================] - 44s 349ms/step - loss: 0.0207 - dice_coef: 0.9793 - iou: 0.9594 - accuracy: 0.9955 - val_loss: 0.2072 - val_dice_coef: 0.7935 - val_iou: 0.6754 - val_accuracy: 0.9532
# Epoch 102/500
# 125/125 [==============================] - ETA: 0s - loss: 0.0209 - dice_coef: 0.9791 - iou: 0.9591 - accuracy: 0.9954
# Epoch 102: val_iou did not improve from 0.69730
# 125/125 [==============================] - 44s 350ms/step - loss: 0.0209 - dice_coef: 0.9791 - iou: 0.9591 - accuracy: 0.9954 - val_loss: 0.2024 - val_dice_coef: 0.7984 - val_iou: 0.6810 - val_accuracy: 0.9547
# Epoch 103/500
# 125/125 [==============================] - ETA: 0s - loss: 0.0207 - dice_coef: 0.9793 - iou: 0.9594 - accuracy: 0.9955
# Epoch 103: val_iou did not improve from 0.69730
# 125/125 [==============================] - 44s 350ms/step - loss: 0.0207 - dice_coef: 0.9793 - iou: 0.9594 - accuracy: 0.9955 - val_loss: 0.1940 - val_dice_coef: 0.8069 - val_iou: 0.6926 - val_accuracy: 0.9569
# Epoch 104/500
# 125/125 [==============================] - ETA: 0s - loss: 0.0205 - dice_coef: 0.9795 - iou: 0.9599 - accuracy: 0.9955
# Epoch 104: val_iou improved from 0.69730 to 0.69935, saving model to /content/drive/MyDrive/Colab Notebooks/Checkpoints_main/pffline_mobv2link_cbam_lasttry/cp.ckpt
# 125/125 [==============================] - 44s 355ms/step - loss: 0.0205 - dice_coef: 0.9795 - iou: 0.9599 - accuracy: 0.9955 - val_loss: 0.1888 - val_dice_coef: 0.8120 - val_iou: 0.6994 - val_accuracy: 0.9567
# Epoch 105/500
# 125/125 [==============================] - ETA: 0s - loss: 0.0204 - dice_coef: 0.9796 - iou: 0.9601 - accuracy: 0.9955
# Epoch 105: val_iou did not improve from 0.69935
# 125/125 [==============================] - 44s 350ms/step - loss: 0.0204 - dice_coef: 0.9796 - iou: 0.9601 - accuracy: 0.9955 - val_loss: 0.2058 - val_dice_coef: 0.7949 - val_iou: 0.6768 - val_accuracy: 0.9544
# Epoch 106/500
# 125/125 [==============================] - ETA: 0s - loss: 0.0204 - dice_coef: 0.9796 - iou: 0.9600 - accuracy: 0.9955
# Epoch 106: val_iou did not improve from 0.69935
# 125/125 [==============================] - 43s 348ms/step - loss: 0.0204 - dice_coef: 0.9796 - iou: 0.9600 - accuracy: 0.9955 - val_loss: 0.1975 - val_dice_coef: 0.8034 - val_iou: 0.6887 - val_accuracy: 0.9557
# Epoch 107/500
# 125/125 [==============================] - ETA: 0s - loss: 0.0203 - dice_coef: 0.9797 - iou: 0.9602 - accuracy: 0.9955
# Epoch 107: val_iou did not improve from 0.69935
# 125/125 [==============================] - 44s 349ms/step - loss: 0.0203 - dice_coef: 0.9797 - iou: 0.9602 - accuracy: 0.9955 - val_loss: 0.1956 - val_dice_coef: 0.8053 - val_iou: 0.6908 - val_accuracy: 0.9570
# Epoch 108/500
# 125/125 [==============================] - ETA: 0s - loss: 0.0204 - dice_coef: 0.9796 - iou: 0.9600 - accuracy: 0.9955
# Epoch 108: val_iou did not improve from 0.69935
# 125/125 [==============================] - 44s 350ms/step - loss: 0.0204 - dice_coef: 0.9796 - iou: 0.9600 - accuracy: 0.9955 - val_loss: 0.2094 - val_dice_coef: 0.7916 - val_iou: 0.6715 - val_accuracy: 0.9561
# Epoch 109/500
# 125/125 [==============================] - ETA: 0s - loss: 0.0201 - dice_coef: 0.9799 - iou: 0.9607 - accuracy: 0.9956
# Epoch 109: val_iou did not improve from 0.69935
# 125/125 [==============================] - 44s 349ms/step - loss: 0.0201 - dice_coef: 0.9799 - iou: 0.9607 - accuracy: 0.9956 - val_loss: 0.1901 - val_dice_coef: 0.8107 - val_iou: 0.6978 - val_accuracy: 0.9573
# Epoch 110/500
# 125/125 [==============================] - ETA: 0s - loss: 0.0204 - dice_coef: 0.9796 - iou: 0.9601 - accuracy: 0.9955
# Epoch 110: val_iou did not improve from 0.69935
# 125/125 [==============================] - 43s 347ms/step - loss: 0.0204 - dice_coef: 0.9796 - iou: 0.9601 - accuracy: 0.9955 - val_loss: 0.2157 - val_dice_coef: 0.7853 - val_iou: 0.6644 - val_accuracy: 0.9542
# Epoch 111/500
# 125/125 [==============================] - ETA: 0s - loss: 0.0204 - dice_coef: 0.9796 - iou: 0.9601 - accuracy: 0.9955
# Epoch 111: val_iou did not improve from 0.69935
# 125/125 [==============================] - 44s 349ms/step - loss: 0.0204 - dice_coef: 0.9796 - iou: 0.9601 - accuracy: 0.9955 - val_loss: 0.2164 - val_dice_coef: 0.7844 - val_iou: 0.6628 - val_accuracy: 0.9546
# Epoch 112/500
# 125/125 [==============================] - ETA: 0s - loss: 0.0199 - dice_coef: 0.9801 - iou: 0.9610 - accuracy: 0.9956
# Epoch 112: val_iou did not improve from 0.69935
# 125/125 [==============================] - 43s 347ms/step - loss: 0.0199 - dice_coef: 0.9801 - iou: 0.9610 - accuracy: 0.9956 - val_loss: 0.1898 - val_dice_coef: 0.8108 - val_iou: 0.6989 - val_accuracy: 0.9574
# Epoch 113/500
# 125/125 [==============================] - ETA: 0s - loss: 0.0196 - dice_coef: 0.9804 - iou: 0.9615 - accuracy: 0.9957
# Epoch 113: val_iou did not improve from 0.69935
# 125/125 [==============================] - 43s 348ms/step - loss: 0.0196 - dice_coef: 0.9804 - iou: 0.9615 - accuracy: 0.9957 - val_loss: 0.1945 - val_dice_coef: 0.8062 - val_iou: 0.6917 - val_accuracy: 0.9569
# Epoch 114/500
# 125/125 [==============================] - ETA: 0s - loss: 0.0196 - dice_coef: 0.9804 - iou: 0.9616 - accuracy: 0.9957
# Epoch 114: val_iou did not improve from 0.69935
# 125/125 [==============================] - 44s 349ms/step - loss: 0.0196 - dice_coef: 0.9804 - iou: 0.9616 - accuracy: 0.9957 - val_loss: 0.1940 - val_dice_coef: 0.8068 - val_iou: 0.6924 - val_accuracy: 0.9577
# Epoch 115/500
# 125/125 [==============================] - ETA: 0s - loss: 0.0194 - dice_coef: 0.9806 - iou: 0.9620 - accuracy: 0.9957
# Epoch 115: val_iou did not improve from 0.69935
# 125/125 [==============================] - 43s 348ms/step - loss: 0.0194 - dice_coef: 0.9806 - iou: 0.9620 - accuracy: 0.9957 - val_loss: 0.2031 - val_dice_coef: 0.7976 - val_iou: 0.6795 - val_accuracy: 0.9561
# Epoch 116/500
# 125/125 [==============================] - ETA: 0s - loss: 0.0195 - dice_coef: 0.9805 - iou: 0.9618 - accuracy: 0.9957
# Epoch 116: val_iou did not improve from 0.69935
# 125/125 [==============================] - 44s 350ms/step - loss: 0.0195 - dice_coef: 0.9805 - iou: 0.9618 - accuracy: 0.9957 - val_loss: 0.2084 - val_dice_coef: 0.7926 - val_iou: 0.6743 - val_accuracy: 0.9547
# Epoch 117/500
# 125/125 [==============================] - ETA: 0s - loss: 0.0192 - dice_coef: 0.9808 - iou: 0.9624 - accuracy: 0.9957
# Epoch 117: val_iou did not improve from 0.69935
# 125/125 [==============================] - 44s 349ms/step - loss: 0.0192 - dice_coef: 0.9808 - iou: 0.9624 - accuracy: 0.9957 - val_loss: 0.2029 - val_dice_coef: 0.7979 - val_iou: 0.6809 - val_accuracy: 0.9565
# Epoch 118/500
# ...
# Epoch 460: val_iou did not improve from 0.71742
# 125/125 [==============================] - 43s 344ms/step - loss: 0.0097 - dice_coef: 0.9903 - iou: 0.9809 - accuracy: 0.9978 - val_loss: 0.1964 - val_dice_coef: 0.8043 - val_iou: 0.6893 - val_accuracy: 0.9578
# Epoch 461/500
# 125/125 [==============================] - ETA: 0s - loss: 0.0097 - dice_coef: 0.9903 - iou: 0.9809 - accuracy: 0.9978
# Epoch 461: val_iou did not improve from 0.71742
# 125/125 [==============================] - 43s 347ms/step - loss: 0.0097 - dice_coef: 0.9903 - iou: 0.9809 - accuracy: 0.9978 - val_loss: 0.1892 - val_dice_coef: 0.8114 - val_iou: 0.6985 - val_accuracy: 0.9589
# Epoch 462/500
# 125/125 [==============================] - ETA: 0s - loss: 0.0096 - dice_coef: 0.9904 - iou: 0.9809 - accuracy: 0.9978
# Epoch 462: val_iou did not improve from 0.71742
# 125/125 [==============================] - 43s 348ms/step - loss: 0.0096 - dice_coef: 0.9904 - iou: 0.9809 - accuracy: 0.9978 - val_loss: 0.1844 - val_dice_coef: 0.8162 - val_iou: 0.7056 - val_accuracy: 0.9603
# Epoch 463/500
# 125/125 [==============================] - ETA: 0s - loss: 0.0096 - dice_coef: 0.9904 - iou: 0.9810 - accuracy: 0.9978
# Epoch 463: val_iou did not improve from 0.71742
# 125/125 [==============================] - 43s 348ms/step - loss: 0.0096 - dice_coef: 0.9904 - iou: 0.9810 - accuracy: 0.9978 - val_loss: 0.1921 - val_dice_coef: 0.8086 - val_iou: 0.6956 - val_accuracy: 0.9584
# Epoch 464/500
# 125/125 [==============================] - ETA: 0s - loss: 0.0096 - dice_coef: 0.9904 - iou: 0.9810 - accuracy: 0.9979
# Epoch 464: val_iou did not improve from 0.71742
# 125/125 [==============================] - 43s 347ms/step - loss: 0.0096 - dice_coef: 0.9904 - iou: 0.9810 - accuracy: 0.9979 - val_loss: 0.1964 - val_dice_coef: 0.8043 - val_iou: 0.6878 - val_accuracy: 0.9578
# Epoch 465/500
# 125/125 [==============================] - ETA: 0s - loss: 0.0098 - dice_coef: 0.9902 - iou: 0.9806 - accuracy: 0.9978
# Epoch 465: val_iou did not improve from 0.71742
# 125/125 [==============================] - 43s 348ms/step - loss: 0.0098 - dice_coef: 0.9902 - iou: 0.9806 - accuracy: 0.9978 - val_loss: 0.1916 - val_dice_coef: 0.8092 - val_iou: 0.6958 - val_accuracy: 0.9553
# Epoch 466/500
# 125/125 [==============================] - ETA: 0s - loss: 0.0097 - dice_coef: 0.9903 - iou: 0.9807 - accuracy: 0.9978
# Epoch 466: val_iou did not improve from 0.71742
# 125/125 [==============================] - 43s 347ms/step - loss: 0.0097 - dice_coef: 0.9903 - iou: 0.9807 - accuracy: 0.9978 - val_loss: 0.1855 - val_dice_coef: 0.8153 - val_iou: 0.7041 - val_accuracy: 0.9592
# Epoch 467/500
# 125/125 [==============================] - ETA: 0s - loss: 0.0096 - dice_coef: 0.9904 - iou: 0.9809 - accuracy: 0.9978
# Epoch 467: val_iou did not improve from 0.71742
# 125/125 [==============================] - 44s 355ms/step - loss: 0.0096 - dice_coef: 0.9904 - iou: 0.9809 - accuracy: 0.9978 - val_loss: 0.1841 - val_dice_coef: 0.8166 - val_iou: 0.7048 - val_accuracy: 0.9599
# Epoch 468/500
# 125/125 [==============================] - ETA: 0s - loss: 0.0096 - dice_coef: 0.9904 - iou: 0.9810 - accuracy: 0.9979
# Epoch 468: val_iou did not improve from 0.71742
# 125/125 [==============================] - 43s 348ms/step - loss: 0.0096 - dice_coef: 0.9904 - iou: 0.9810 - accuracy: 0.9979 - val_loss: 0.1862 - val_dice_coef: 0.8145 - val_iou: 0.7034 - val_accuracy: 0.9586
# Epoch 469/500
# 125/125 [==============================] - ETA: 0s - loss: 0.0096 - dice_coef: 0.9904 - iou: 0.9810 - accuracy: 0.9978
# Epoch 469: val_iou did not improve from 0.71742
# 125/125 [==============================] - 44s 348ms/step - loss: 0.0096 - dice_coef: 0.9904 - iou: 0.9810 - accuracy: 0.9978 - val_loss: 0.1861 - val_dice_coef: 0.8146 - val_iou: 0.7034 - val_accuracy: 0.9587
# Epoch 470/500
# 125/125 [==============================] - ETA: 0s - loss: 0.0096 - dice_coef: 0.9904 - iou: 0.9810 - accuracy: 0.9978
# Epoch 470: val_iou did not improve from 0.71742
# 125/125 [==============================] - 43s 348ms/step - loss: 0.0096 - dice_coef: 0.9904 - iou: 0.9810 - accuracy: 0.9978 - val_loss: 0.1934 - val_dice_coef: 0.8073 - val_iou: 0.6923 - val_accuracy: 0.9571
# Epoch 471/500
# 125/125 [==============================] - ETA: 0s - loss: 0.0095 - dice_coef: 0.9905 - iou: 0.9813 - accuracy: 0.9979
# Epoch 471: val_iou did not improve from 0.71742
# 125/125 [==============================] - 44s 348ms/step - loss: 0.0095 - dice_coef: 0.9905 - iou: 0.9813 - accuracy: 0.9979 - val_loss: 0.1931 - val_dice_coef: 0.8076 - val_iou: 0.6937 - val_accuracy: 0.9574
# Epoch 472/500
# 125/125 [==============================] - ETA: 0s - loss: 0.0095 - dice_coef: 0.9905 - iou: 0.9812 - accuracy: 0.9979
# Epoch 472: val_iou did not improve from 0.71742
# 125/125 [==============================] - 43s 348ms/step - loss: 0.0095 - dice_coef: 0.9905 - iou: 0.9812 - accuracy: 0.9979 - val_loss: 0.1927 - val_dice_coef: 0.8080 - val_iou: 0.6933 - val_accuracy: 0.9584
# Epoch 473/500
# 125/125 [==============================] - ETA: 0s - loss: 0.0094 - dice_coef: 0.9906 - iou: 0.9814 - accuracy: 0.9979
# Epoch 473: val_iou did not improve from 0.71742
# 125/125 [==============================] - 44s 349ms/step - loss: 0.0094 - dice_coef: 0.9906 - iou: 0.9814 - accuracy: 0.9979 - val_loss: 0.1958 - val_dice_coef: 0.8048 - val_iou: 0.6895 - val_accuracy: 0.9578
# Epoch 474/500
# 125/125 [==============================] - ETA: 0s - loss: 0.0093 - dice_coef: 0.9907 - iou: 0.9815 - accuracy: 0.9979
# Epoch 474: val_iou did not improve from 0.71742
# 125/125 [==============================] - 43s 347ms/step - loss: 0.0093 - dice_coef: 0.9907 - iou: 0.9815 - accuracy: 0.9979 - val_loss: 0.1848 - val_dice_coef: 0.8158 - val_iou: 0.7034 - val_accuracy: 0.9599
# Epoch 475/500
# 125/125 [==============================] - ETA: 0s - loss: 0.0096 - dice_coef: 0.9904 - iou: 0.9809 - accuracy: 0.9978
# Epoch 475: val_iou did not improve from 0.71742
# 125/125 [==============================] - 43s 348ms/step - loss: 0.0096 - dice_coef: 0.9904 - iou: 0.9809 - accuracy: 0.9978 - val_loss: 0.1877 - val_dice_coef: 0.8129 - val_iou: 0.7006 - val_accuracy: 0.9589
# Epoch 476/500
# 125/125 [==============================] - ETA: 0s - loss: 0.0097 - dice_coef: 0.9903 - iou: 0.9808 - accuracy: 0.9978
# Epoch 476: val_iou did not improve from 0.71742
# 125/125 [==============================] - 43s 348ms/step - loss: 0.0097 - dice_coef: 0.9903 - iou: 0.9808 - accuracy: 0.9978 - val_loss: 0.1895 - val_dice_coef: 0.8113 - val_iou: 0.6983 - val_accuracy: 0.9582
# Epoch 477/500
# 125/125 [==============================] - ETA: 0s - loss: 0.0095 - dice_coef: 0.9905 - iou: 0.9812 - accuracy: 0.9979
# Epoch 477: val_iou did not improve from 0.71742
# 125/125 [==============================] - 43s 347ms/step - loss: 0.0095 - dice_coef: 0.9905 - iou: 0.9812 - accuracy: 0.9979 - val_loss: 0.1892 - val_dice_coef: 0.8114 - val_iou: 0.6988 - val_accuracy: 0.9582
# Epoch 478/500
# 125/125 [==============================] - ETA: 0s - loss: 0.0094 - dice_coef: 0.9906 - iou: 0.9814 - accuracy: 0.9979
# Epoch 478: val_iou did not improve from 0.71742
# 125/125 [==============================] - 44s 349ms/step - loss: 0.0094 - dice_coef: 0.9906 - iou: 0.9814 - accuracy: 0.9979 - val_loss: 0.1852 - val_dice_coef: 0.8154 - val_iou: 0.7030 - val_accuracy: 0.9593
# Epoch 479/500
# 125/125 [==============================] - ETA: 0s - loss: 0.0094 - dice_coef: 0.9906 - iou: 0.9813 - accuracy: 0.9979
# Epoch 479: val_iou did not improve from 0.71742
# 125/125 [==============================] - 43s 347ms/step - loss: 0.0094 - dice_coef: 0.9906 - iou: 0.9813 - accuracy: 0.9979 - val_loss: 0.1931 - val_dice_coef: 0.8076 - val_iou: 0.6923 - val_accuracy: 0.9580
# Epoch 480/500
# 125/125 [==============================] - ETA: 0s - loss: 0.0096 - dice_coef: 0.9904 - iou: 0.9810 - accuracy: 0.9979
# Epoch 480: val_iou did not improve from 0.71742
# 125/125 [==============================] - 43s 348ms/step - loss: 0.0096 - dice_coef: 0.9904 - iou: 0.9810 - accuracy: 0.9979 - val_loss: 0.1854 - val_dice_coef: 0.8152 - val_iou: 0.7030 - val_accuracy: 0.9592
# Epoch 481/500
# 125/125 [==============================] - ETA: 0s - loss: 0.0095 - dice_coef: 0.9905 - iou: 0.9813 - accuracy: 0.9979
# Epoch 481: val_iou did not improve from 0.71742
# 125/125 [==============================] - 43s 347ms/step - loss: 0.0095 - dice_coef: 0.9905 - iou: 0.9813 - accuracy: 0.9979 - val_loss: 0.2035 - val_dice_coef: 0.7971 - val_iou: 0.6788 - val_accuracy: 0.9570
# Epoch 482/500
# 125/125 [==============================] - ETA: 0s - loss: 0.0094 - dice_coef: 0.9906 - iou: 0.9813 - accuracy: 0.9979
# Epoch 482: val_iou did not improve from 0.71742
# 125/125 [==============================] - 43s 346ms/step - loss: 0.0094 - dice_coef: 0.9906 - iou: 0.9813 - accuracy: 0.9979 - val_loss: 0.1845 - val_dice_coef: 0.8161 - val_iou: 0.7053 - val_accuracy: 0.9591
# Epoch 483/500
# 125/125 [==============================] - ETA: 0s - loss: 0.0094 - dice_coef: 0.9906 - iou: 0.9814 - accuracy: 0.9979
# Epoch 483: val_iou did not improve from 0.71742
# 125/125 [==============================] - 43s 346ms/step - loss: 0.0094 - dice_coef: 0.9906 - iou: 0.9814 - accuracy: 0.9979 - val_loss: 0.1913 - val_dice_coef: 0.8094 - val_iou: 0.6956 - val_accuracy: 0.9584
# Epoch 484/500
# 125/125 [==============================] - ETA: 0s - loss: 0.0093 - dice_coef: 0.9907 - iou: 0.9815 - accuracy: 0.9979
# Epoch 484: val_iou did not improve from 0.71742
# 125/125 [==============================] - 43s 348ms/step - loss: 0.0093 - dice_coef: 0.9907 - iou: 0.9815 - accuracy: 0.9979 - val_loss: 0.1895 - val_dice_coef: 0.8111 - val_iou: 0.6976 - val_accuracy: 0.9588
# Epoch 485/500
# 125/125 [==============================] - ETA: 0s - loss: 0.0092 - dice_coef: 0.9908 - iou: 0.9817 - accuracy: 0.9979
# Epoch 485: val_iou did not improve from 0.71742
# 125/125 [==============================] - 43s 347ms/step - loss: 0.0092 - dice_coef: 0.9908 - iou: 0.9817 - accuracy: 0.9979 - val_loss: 0.1950 - val_dice_coef: 0.8057 - val_iou: 0.6906 - val_accuracy: 0.9578
# Epoch 486/500
# 125/125 [==============================] - ETA: 0s - loss: 0.0093 - dice_coef: 0.9907 - iou: 0.9815 - accuracy: 0.9979
# Epoch 486: val_iou did not improve from 0.71742
# 125/125 [==============================] - 43s 348ms/step - loss: 0.0093 - dice_coef: 0.9907 - iou: 0.9815 - accuracy: 0.9979 - val_loss: 0.1951 - val_dice_coef: 0.8055 - val_iou: 0.6894 - val_accuracy: 0.9584
# Epoch 487/500
# 125/125 [==============================] - ETA: 0s - loss: 0.0093 - dice_coef: 0.9907 - iou: 0.9815 - accuracy: 0.9979
# Epoch 487: val_iou did not improve from 0.71742
# 125/125 [==============================] - 44s 349ms/step - loss: 0.0093 - dice_coef: 0.9907 - iou: 0.9815 - accuracy: 0.9979 - val_loss: 0.1892 - val_dice_coef: 0.8115 - val_iou: 0.6975 - val_accuracy: 0.9588
# Epoch 488/500
# 125/125 [==============================] - ETA: 0s - loss: 0.0093 - dice_coef: 0.9907 - iou: 0.9816 - accuracy: 0.9979
# Epoch 488: val_iou did not improve from 0.71742
# 125/125 [==============================] - 44s 349ms/step - loss: 0.0093 - dice_coef: 0.9907 - iou: 0.9816 - accuracy: 0.9979 - val_loss: 0.1869 - val_dice_coef: 0.8138 - val_iou: 0.7000 - val_accuracy: 0.9595
# Epoch 489/500
# 125/125 [==============================] - ETA: 0s - loss: 0.0093 - dice_coef: 0.9907 - iou: 0.9816 - accuracy: 0.9979
# Epoch 489: val_iou did not improve from 0.71742
# 125/125 [==============================] - 44s 349ms/step - loss: 0.0093 - dice_coef: 0.9907 - iou: 0.9816 - accuracy: 0.9979 - val_loss: 0.1892 - val_dice_coef: 0.8115 - val_iou: 0.6973 - val_accuracy: 0.9578
# Epoch 490/500
# 125/125 [==============================] - ETA: 0s - loss: 0.0093 - dice_coef: 0.9907 - iou: 0.9816 - accuracy: 0.9979
# Epoch 490: val_iou did not improve from 0.71742
# 125/125 [==============================] - 44s 349ms/step - loss: 0.0093 - dice_coef: 0.9907 - iou: 0.9816 - accuracy: 0.9979 - val_loss: 0.1915 - val_dice_coef: 0.8093 - val_iou: 0.6952 - val_accuracy: 0.9580
# Epoch 491/500
# 125/125 [==============================] - ETA: 0s - loss: 0.0092 - dice_coef: 0.9908 - iou: 0.9819 - accuracy: 0.9979
# Epoch 491: val_iou did not improve from 0.71742
# 125/125 [==============================] - 43s 348ms/step - loss: 0.0092 - dice_coef: 0.9908 - iou: 0.9819 - accuracy: 0.9979 - val_loss: 0.1879 - val_dice_coef: 0.8128 - val_iou: 0.6993 - val_accuracy: 0.9597
# Epoch 492/500
# 125/125 [==============================] - ETA: 0s - loss: 0.0092 - dice_coef: 0.9908 - iou: 0.9818 - accuracy: 0.9979
# Epoch 492: val_iou did not improve from 0.71742
# 125/125 [==============================] - 43s 348ms/step - loss: 0.0092 - dice_coef: 0.9908 - iou: 0.9818 - accuracy: 0.9979 - val_loss: 0.1861 - val_dice_coef: 0.8146 - val_iou: 0.7019 - val_accuracy: 0.9595
# Epoch 493/500
# 125/125 [==============================] - ETA: 0s - loss: 0.0092 - dice_coef: 0.9908 - iou: 0.9818 - accuracy: 0.9979
# Epoch 493: val_iou did not improve from 0.71742
# 125/125 [==============================] - 44s 349ms/step - loss: 0.0092 - dice_coef: 0.9908 - iou: 0.9818 - accuracy: 0.9979 - val_loss: 0.1852 - val_dice_coef: 0.8155 - val_iou: 0.7037 - val_accuracy: 0.9592
# Epoch 494/500
# 125/125 [==============================] - ETA: 0s - loss: 0.0091 - dice_coef: 0.9909 - iou: 0.9820 - accuracy: 0.9980
# Epoch 494: val_iou did not improve from 0.71742
# 125/125 [==============================] - 44s 348ms/step - loss: 0.0091 - dice_coef: 0.9909 - iou: 0.9820 - accuracy: 0.9980 - val_loss: 0.1889 - val_dice_coef: 0.8118 - val_iou: 0.6994 - val_accuracy: 0.9591
# Epoch 495/500
# 125/125 [==============================] - ETA: 0s - loss: 0.0091 - dice_coef: 0.9909 - iou: 0.9820 - accuracy: 0.9980
# Epoch 495: val_iou did not improve from 0.71742
# 125/125 [==============================] - 43s 348ms/step - loss: 0.0091 - dice_coef: 0.9909 - iou: 0.9820 - accuracy: 0.9980 - val_loss: 0.1925 - val_dice_coef: 0.8081 - val_iou: 0.6952 - val_accuracy: 0.9583
# Epoch 496/500
# 125/125 [==============================] - ETA: 0s - loss: 0.0091 - dice_coef: 0.9909 - iou: 0.9819 - accuracy: 0.9980
# Epoch 496: val_iou did not improve from 0.71742
# 125/125 [==============================] - 43s 346ms/step - loss: 0.0091 - dice_coef: 0.9909 - iou: 0.9819 - accuracy: 0.9980 - val_loss: 0.2026 - val_dice_coef: 0.7982 - val_iou: 0.6796 - val_accuracy: 0.9576
# Epoch 497/500
# 125/125 [==============================] - ETA: 0s - loss: 0.0092 - dice_coef: 0.9908 - iou: 0.9817 - accuracy: 0.9979
# Epoch 497: val_iou did not improve from 0.71742
# 125/125 [==============================] - 44s 348ms/step - loss: 0.0092 - dice_coef: 0.9908 - iou: 0.9817 - accuracy: 0.9979 - val_loss: 0.1859 - val_dice_coef: 0.8148 - val_iou: 0.7042 - val_accuracy: 0.9587
# Epoch 498/500
# 125/125 [==============================] - ETA: 0s - loss: 0.0095 - dice_coef: 0.9905 - iou: 0.9812 - accuracy: 0.9979
# Epoch 498: val_iou did not improve from 0.71742
# 125/125 [==============================] - 43s 347ms/step - loss: 0.0095 - dice_coef: 0.9905 - iou: 0.9812 - accuracy: 0.9979 - val_loss: 0.2037 - val_dice_coef: 0.7970 - val_iou: 0.6792 - val_accuracy: 0.9564
# Epoch 499/500
# 125/125 [==============================] - ETA: 0s - loss: 0.0094 - dice_coef: 0.9906 - iou: 0.9814 - accuracy: 0.9979
# Epoch 499: val_iou did not improve from 0.71742
# 125/125 [==============================] - 44s 349ms/step - loss: 0.0094 - dice_coef: 0.9906 - iou: 0.9814 - accuracy: 0.9979 - val_loss: 0.1941 - val_dice_coef: 0.8066 - val_iou: 0.6922 - val_accuracy: 0.9570
# Epoch 500/500
# 125/125 [==============================] - ETA: 0s - loss: 0.0092 - dice_coef: 0.9908 - iou: 0.9818 - accuracy: 0.9979
# Epoch 500: val_iou did not improve from 0.71742
# 125/125 [==============================] - 43s 347ms/step - loss: 0.0092 - dice_coef: 0.9908 - iou: 0.9818 - accuracy: 0.9979 - val_loss: 0.1890 - val_dice_coef: 0.8117 - val_iou: 0.6984 - val_accuracy: 0.9594

# %%
import matplotlib.pyplot as plt
plt.style.use("ggplot")
plt.figure()
N = 500
plt.plot(np.arange(0,N), history.history["loss"], label="train_loss")
plt.plot(np.arange(0,N), history.history["val_loss"], label = "val_loss")
plt.plot(np.arange(0,N), history.history["iou"], label = "train_iou_score")
plt.plot(np.arange(0,N), history.history["val_iou"], label = "val_iou_score")
plt.legend(loc="center right")
plt.title("Training Loss and IOU plot")
plt.xlabel("Epochs")
plt.savefig('UNET_Traininerrorplot_SEGMENTATION_RGB.png')

# %%
plt.plot(np.arange(0,N), history.history["accuracy"])
plt.title("Training accuracy plot")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
# Out:
# Text(0, 0.5, 'Accuracy')

# %%
plt.plot(np.arange(0,N), history.history["val_accuracy"], label = "val_accuracy")
plt.title("Validation accuracy plot")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
# Out:
# Text(0, 0.5, 'Accuracy')

# %%
plt.plot(np.arange(0,N), history.history["val_loss"], label = "val_loss")
plt.title("Validation loss plot")
plt.xlabel("Epochs")
plt.ylabel("Loss")
# Out:
# Text(0, 0.5, 'Loss')

# %%
plt.plot(np.arange(0,N), history.history["loss"], label = "val_loss")
plt.title("Training loss plot")
plt.xlabel("Epochs")
plt.ylabel("Loss")
# Out:
# Text(0, 0.5, 'Loss')

# %%
y_pred=model.predict(X_test)

# %%
## Jaccard Index ( IoU )

#y_pred=model.predict(X_test)
y_pred_thresholded = y_pred > 0.5

intersection = np.logical_and(Y_test, y_pred_thresholded)
union = np.logical_or(Y_test, y_pred_thresholded)
iou_score = np.sum(intersection) / np.sum(union)
print("IoU socre is: ", iou_score)
# Out:
# IoU socre is:  0.6965839044260557

# %%
#Prediction test
import random
import numpy as np
image_number = random.randint(0, len(X_test))
plt.figure(figsize=(12, 6))
plt.subplot(121)
plt.imshow(X_test[image_number])
plt.subplot(122)
plt.imshow(array_to_img(y_pred[image_number]), cmap='gray')
plt.show()

# %%
model.load_weights('/content/drive/MyDrive/Colab Notebooks/Checkpoints_main/pffline_mobv2link_cbam_lasttry/cp.ckpt')
y_pred=model.predict(X_test)

# %%
## Jaccard Index ( IoU )

#y_pred=model.predict(X_test)
y_pred_thresholded = y_pred > 0.5

intersection = np.logical_and(Y_test, y_pred_thresholded)
union = np.logical_or(Y_test, y_pred_thresholded)
iou_score = np.sum(intersection) / np.sum(union)
print("IoU socre is: ", iou_score)
# Out:
# IoU socre is:  0.7133230695916478

# %%
 #Prediction test
import random
import numpy as np
image_number = random.randint(0, len(X_test))
plt.figure(figsize=(12, 6))
plt.subplot(121)
plt.imshow(X_test[image_number])
plt.subplot(122)
plt.imshow(array_to_img(y_pred[image_number]), cmap='gray')
plt.show()

# %%
model.save('/content/drive/MyDrive/Colab Notebooks/offlinen.h5')
model.save_weights('/content/drive/MyDrive/Colab Notebooks/offline.h5')
